# %% [markdown]
# # Create Lexicon Sentiment Score using PMI score
# Created by Sabrina Tiun (Julai, 2023)

# %% [markdown]
# References:<br>
# [1]https://www.researchgate.net/publication/332372512_Aspect_Extraction_and_Sentiment_Analysis_in_User_Reviews_in_Russian_about_Bank_Service_Quality#pf2 <br>

# %%
import turicreate as tc

# %%
#load sFrame lexicon dict
sf_train = tc.load_sframe('sframe_train')
sf_train
# Out:
# Columns:
# 	sentiment	str
# 	text	list
#
# Rows: 2
#
# Data:
# +-----------+-------------------------------+
# | sentiment |              text             |
# +-----------+-------------------------------+
# |    pos    | [sedap, taste, sedap, rasa... |
# |    neg    | [barang, tak, pos, apa, ce... |
# +-----------+-------------------------------+
# [2 rows x 2 columns]

# %% [markdown]
# ### PMI lexicon score
#
# Formula (e.g to calculate the target word, w in class positive, pos):<br>
# <b>PMI (w,pos) = log 2 * ( (count(w,pos)* N)/ (count (w) * count (pos)) <p></b>
# count(w, pos) is the count of word w in positive reviews [ count_w_neg, count_w_pos]<br>
# N is total number of words in all the reviews [N] <br>
# count(w) is the count of word w in all the reviews [count_neg]<br>
# count(pos) is the total number of words in positive review [count_pos].<br>

# %%
docs = tc.SArray(sf_train['text'])
docs
# Out:
# dtype: list
# Rows: 2
# [['sedap', 'taste', 'sedap', 'rasa', 'coklat', 'semua', 'cukup', 'quality', 'good', 'quality', 'baik', 'taste', 'sedap', 'belikan', 'untuk', 'adik', 'yang', 'mengidam', 'sangat', 'nak', 'batang', 'buruk', 'tawakal', 'saja', 'beli', 'ni', 'masa', 'itu', 'tak', 'sangka', 'adik', 'cakap', 'sedap', 'kita', 'pula', 'tertelan', 'air', 'liur', 'haha', 'kena', 'beli', 'juga', 'nanti', 'untuk', 'diri', 'pula', 'ni', 'alhamdulillah', 'sampai', 'dah', 'sedap', 'tapi', 'hancur', 'kena', 'pakai', 'sudu', 'makan', 'padan', 'la', 'beli', 'time', 'shocking', 'sale', 'bungkusan', 'selamat', 'tak', 'dak', 'pecah', 'dah', 'banyak', 'kali', 'repeat', 'memang', 'tor', 'baik', 'alhamdulillah', 'sedap', 'sangat', 'sangat', 'beli', 'la', 'jangan', 'ragu', 'lagi', 'sampai', 'dengan', 'selamat', 'repeat', 'order', 'berkali', 'sudah', 'terima', 'kasih', 'thank', 'you', 'barang', 'baru', 'saja', 'dterima', 'wah', 'bekas', 'yang', 'bagus', 'tak', 'mudah', 'pecah', 'thank', 'you', 'sekali', 'lagi', 'pada', 'seller', 'mengambil', 'perhatian', 'atas', 'komen', 'saya', 'terdahulu', 'batang', 'buruk', 'really', 'marvellous', 'sedap', 'sangat', 'ter', 'baik', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'pergi', 'memang', 'sedap', 'ha', 'rugi', 'hangpa', 'dak', 'beli', 'oi', 'sedap', 'tak', 'boleh', 'dibawa', 'bincang', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'ter', 'baik', 'items', 'safely', 'arived', 'not', 'taste', 'yet', 'hopefully', 'good', 'haha', 'thank', 'you', 'lot', 'seller', 'for', 'following', 'up', 'the', 'tracking', 'itesm', 'rasa', 'sedap', 'dan', 'rangup', 'kuih', 'rasa', 'fresh', 'dan', 'tak', 'rasa', 'lama', 'packaging', 'kemas', 'berbaloi', 'beli', 'walaupun', 'harga', 'agak', 'mahal', 'berbanding', 'yang', 'lain', 'kualiti', 'terima', 'kasih', 'seller', 'saya', 'beli', 'delivery', 'sangat', 'cepat', 'and', 'packaging', 'bagus', 'yang', 'penting', 'rasa', 'sangat', 'sedap', 'parents', 'pun', 'suka', 'terus', 'masuk', 'botol', 'buat', 'snacks', 'boleh', 'repeat', 'order', 'nanti', 'thank', 'you', 'you', 'rasa', 'ok', 'tapi', 'kalau', 'lagi', 'ranggup', 'lagi', 'sedap', 'overal', 'ok', 'peratusan', 'hancur', 'tak', 'banyak', 'sangat', 'boleh', 'makan', 'la', 'tapi', 'pernah', 'rasa', 'lagi', 'yang', 'betul', 'sedap', 'nak', 'sangat', 'cari', 'yang', 'rasa', 'kacang', 'hijau', 'tapi', 'tak', 'dapat', 'so', 'far', 'yang', 'ni', 'garing', 'la', 'sedap', 'juga', 'taste', 'good', 'quality', 'good', 'nasib', 'baik', 'tak', 'hancur', 'jadi', 'sagun', 'bila', 'terperap', 'lama', 'di', 'hub', 'quality', 'baik', 'taste', 'sedap', 'belikan', 'untuk', 'adik', 'yang', 'mengidam', 'sangat', 'nak', 'batang', 'buruk', 'tawakal', 'saja', 'beli', 'ni', 'masa', 'itu', 'tak', 'sangka', 'adik', 'cakap', 'sedap', 'kita', 'pula', 'tertelan', 'air', 'liur', 'haha', 'kena', 'beli', 'juga', 'nanti', 'untuk', 'diri', 'pula', 'ni', 'alhamdulillah', 'sampai', 'dah', 'sedap', 'tapi', 'hancur', 'kena', 'pakai', 'sudu', 'makan', 'padan', 'la', 'beli', 'time', 'shocking', 'sale', 'bungkusan', 'selamat', 'tak', 'dak', 'pecah', 'dah', 'banyak', 'kali', 'repeat', 'memang', 'tor', 'baik', 'alhamdulillah', 'sedap', 'sangat', 'sangat', 'beli', 'la', 'jangan', 'ragu', 'lagi', 'sa ...

# %% [markdown]
# ### a. count frequency of specific word --> count (w)

# %%
#flatten list (combine review list of negative and postive)
def flatten_concatenation(matrix):
    flat_list = []
    for row in matrix:
        flat_list += row
        return flat_list

all_words_lista = flatten_concatenation(docs)
all_words_lista #contains all words from both classes
# Out:
# ['sedap',
#  'taste',
#  'sedap',
#  'rasa',
#  'coklat',
#  'semua',
#  'cukup',
#  'quality',
#  'good',
#  'quality',
#  'baik',
#  'taste',
#  'sedap',
#  'belikan',
#  'untuk',
#  'adik',
#  'yang',
#  'mengidam',
#  'sangat',
#  'nak',
#  'batang',
#  'buruk',
#  'tawakal',
#  'saja',
#  'beli',
#  'ni',
#  'masa',
#  'itu',
#  'tak',
#  'sangka',
#  'adik',
#  'cakap',
#  'sedap',
#  'kita',
#  'pula',
#  'tertelan',
#  'air',
#  'liur',
#  'haha',
#  'kena',
#  'beli',
#  'juga',
#  'nanti',
#  'untuk',
#  'diri',
#  'pula',
#  'ni',
#  'alhamdulillah',
#  'sampai',
#  'dah',
#  'sedap',
#  'tapi',
#  'hancur',
#  'kena',
#  'pakai',
#  'sudu',
#  'makan',
#  'padan',
#  'la',
#  'beli',
#  'time',
#  'shocking',
#  'sale',
#  'bungkusan',
#  'selamat',
#  'tak',
#  'dak',
#  'pecah',
#  'dah',
#  'banyak',
#  'kali',
#  'repeat',
#  'memang',
#  'tor',
#  'baik',
#  'alhamdulillah',
#  'sedap',
#  'sangat',
#  'sangat',
#  'beli',
#  'la',
#  'jangan',
#  'ragu',
#  'lagi',
#  'sampai',
#  'dengan',
#  'selamat',
#  'repeat',
#  'order',
#  'berkali',
#  'sudah',
#  'terima',
#  'kasih',
#  'thank',
#  'you',
#  'barang',
#  'baru',
#  'saja',
#  'dterima',
#  'wah',
#  'bekas',
#  'yang',
#  'bagus',
#  'tak',
#  'mudah',
#  'pecah',
#  'thank',
#  'you',
#  'sekali',
#  'lagi',
#  'pada',
#  'seller',
#  'mengambil',
#  'perhatian',
#  'atas',
#  'komen',
#  'saya',
#  'terdahulu',
#  'batang',
#  'buruk',
#  'really',
#  'marvellous',
#  'sedap',
#  'sangat',
#  'ter',
#  'baik',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'pergi',
#  'memang',
#  'sedap',
#  'ha',
#  'rugi',
#  'hangpa',
#  'dak',
#  'beli',
#  'oi',
#  'sedap',
#  'tak',
#  'boleh',
#  'dibawa',
#  'bincang',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'items',
#  'safely',
#  'arived',
#  'not',
#  'taste',
#  'yet',
#  'hopefully',
#  'good',
#  'haha',
#  'thank',
#  'you',
#  'lot',
#  'seller',
#  'for',
#  'following',
#  'up',
#  'the',
#  'tracking',
#  'itesm',
#  'rasa',
#  'sedap',
#  'dan',
#  'rangup',
#  'kuih',
#  'rasa',
#  'fresh',
#  'dan',
#  'tak',
#  'rasa',
#  'lama',
#  'packaging',
#  'kemas',
#  'berbaloi',
#  'beli',
#  'walaupun',
#  'harga',
#  'agak',
#  'mahal',
#  'berbanding',
#  'yang',
#  'lain',
#  'kualiti',
#  'terima',
#  'kasih',
#  'seller',
#  'saya',
#  'beli',
#  'delivery',
#  'sangat',
#  'cepat',
#  'and',
#  'packaging',
#  'bagus',
#  'yang',
#  'penting',
#  'rasa',
#  'sangat',
#  'sedap',
#  'parents',
#  'pun',
#  'suka',
#  'terus',
#  'masuk',
#  'botol',
#  'buat',
#  'snacks',
#  'boleh',
#  'repeat',
#  'order',
#  'nanti',
#  'thank',
#  'you',
#  'you',
#  'rasa',
#  'ok',
#  'tapi',
#  'kalau',
#  'lagi',
#  'ranggup',
#  'lagi',
#  'sedap',
#  'overal',
#  'ok',
#  'peratusan',
#  'hancur',
#  'tak',
#  'banyak',
#  'sangat',
#  'boleh',
#  'makan',
#  'la',
#  'tapi',
#  'pernah',
#  'rasa',
#  'lagi',
#  'yang',
#  'betul',
#  'sedap',
#  'nak',
#  'sangat',
#  'cari',
#  'yang',
#  'rasa',
#  'kacang',
#  'hijau',
#  'tapi',
#  'tak',
#  'dapat',
#  'so',
#  'far',
#  'yang',
#  'ni',
#  'garing',
#  'la',
#  'sedap',
#  'juga',
#  'taste',
#  'good',
#  'quality',
#  'good',
#  'nasib',
#  'baik',
#  'tak',
#  'hancur',
#  'jadi',
#  'sagun',
#  'bila',
#  'terperap',
#  'lama',
#  'di',
#  'hub',
#  'quality',
#  'baik',
#  'taste',
#  'sedap',
#  'belikan',
#  'untuk',
#  'adik',
#  'yang',
#  'mengidam',
#  'sangat',
#  'nak',
#  'batang',
#  'buruk',
#  'tawakal',
#  'saja',
#  'beli',
#  'ni',
#  'masa',
#  'itu',
#  'tak',
#  'sangka',
#  'adik',
#  'cakap',
#  'sedap',
#  'kita',
#  'pula',
#  'tertelan',
#  'air',
#  'liur',
#  'haha',
#  'kena',
#  'beli',
#  'juga',
#  'nanti',
#  'untuk',
#  'diri',
#  'pula',
#  'ni',
#  'alhamdulillah',
#  'sampai',
#  'dah',
#  'sedap',
#  'tapi',
#  'hancur',
#  'kena',
#  'pakai',
#  'sudu',
#  'makan',
#  'padan',
#  'la',
#  'beli',
#  'time',
#  'shocking',
#  'sale',
#  'bungkusan',
#  'selamat',
#  'tak',
#  'dak',
#  'pecah',
#  'dah',
#  'banyak',
#  'kali',
#  'repeat',
#  'memang',
#  'tor',
#  'baik',
#  'alhamdulillah',
#  'sedap',
#  'sangat',
#  'sangat',
#  'beli',
#  'la',
#  'jangan',
#  'ragu',
#  'lagi',
#  'sampai',
#  'dengan',
#  'selamat',
#  'repeat',
#  'order',
#  'berkali',
#  'sudah',
#  'terima',
#  'kasih',
#  'thank',
#  'you',
#  'barang',
#  'baru',
#  'saja',
#  'dterima',
#  'wah',
#  'bekas',
#  'yang',
#  'bagus',
#  'tak',
#  'mudah',
#  'pecah',
#  'thank',
#  'you',
#  'sekali',
#  'lagi',
#  'pada',
#  'seller',
#  'mengambil',
#  'perhatian',
#  'atas',
#  'komen',
#  'saya',
#  'terdahulu',
#  'batang',
#  'buruk',
#  'really',
#  'marvellous',
#  'sedap',
#  'sangat',
#  'ter',
#  'baik',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'pergi',
#  'memang',
#  'sedap',
#  'ha',
#  'rugi',
#  'hangpa',
#  'dak',
#  'beli',
#  'oi',
#  'sedap',
#  'tak',
#  'boleh',
#  'dibawa',
#  'bincang',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'alhamdulillah',
#  'parcel',
#  'selamat',
#  'sampai',
#  'kejap',
#  'time',
#  'beli',
#  'dari',
#  'seller',
#  'harap',
#  'memuaskan',
#  'thank',
#  'you',
#  'seller',
#  'quality',
#  'ok',
#  'taste',
#  'ok',
#  'penghantaran',
#  'cepat',
#  'barang',
#  'dibalut',
#  'dengan',
#  'bub',
#  'la',
#  'wrap',
#  'rasa',
#  'ok',
#  'tak',
#  'berapa',
#  'kuat',
#  'biasa',
#  'saja',
#  'delivery',
#  'laju',
#  'bethol',
#  'kerepek',
#  'sedap',
#  'gila',
#  'boleh',
#  'makan',
#  'sambil',
#  'tengok',
#  'cerita',
#  'cukup',
#  'derita',
#  'itu',
#  'hehe',
#  'ok',
#  'alhamdulillah',
#  'kuih',
#  'sedap',
#  'rangup',
#  'sedang',
#  'penuh',
#  'flavour',
#  'saya',
#  'suka',
#  'harga',
#  'sangat',
#  'berpatutan',
#  'tqtqtq',
#  'tqtqtq',
#  'tqtqtq',
#  'tqtqtq',
#  'tqtqtq',
#  'tqtqtq',
#  'tqtqtq',
#  'taste',
#  'sedap',
#  'sungguh',
#  'quality',
#  'not',
#  'bad',
#  'yum',
#  'yum',
#  'yum',
#  'kuih',
#  'siput',
#  'selamat',
#  'diterima',
#  'dalam',
#  'bungkusan',
#  'yang',
#  'kemas',
#  'rasa',
#  'pun',
#  'sedap',
#  'terima',
#  'kasih',
#  'seller',
#  'ok',
#  'sedap',
#  'rangup',
#  'cepat',
#  'juga',
#  'pos',
#  'packaging',
#  'pun',
#  'ok',
#  'kotak',
#  'kemek',
#  'sikit',
#  'tapi',
#  'dalam',
#  'ok',
#  'dah',
#  'berapa',
#  'kali',
#  'repeat',
#  'dah',
#  'thank',
#  'you',
#  'seller',
#  'aku',
#  'beli',
#  'sedap',
#  'seller',
#  'pos',
#  'cepat',
#  'barang',
#  'tapi',
#  'ninja',
#  'van',
#  'la',
#  'thank',
#  'you',
#  'seller',
#  'taste',
#  'sedap',
#  'quality',
#  'baik',
#  'barang',
#  'diterima',
#  'dalam',
#  'keadaan',
#  'baik',
#  'penghantaran',
#  'pantas',
#  'kuih',
#  'siput',
#  'pun',
#  'sedap',
#  'sangat',
#  'taste',
#  'sedap',
#  'rangup',
#  'quality',
#  'baik',
#  'penghantaran',
#  'pantas',
#  'barang',
#  'diterima',
#  'dalam',
#  'keadaan',
#  'baik',
#  'kuih',
#  'siput',
#  'pun',
#  'sedap',
#  'ter',
#  'baik',
#  'terima',
#  'kasih',
#  'seller',
#  'barang',
#  'sudah',
#  'diterima',
#  'terima',
#  'kasih',
#  'seller',
#  'saya',
#  'beli',
#  'ya',
#  'penghantaran',
#  'super',
#  'laju',
#  'bungkusan',
#  'ter',
#  'baik',
#  'bub',
#  'la',
#  'wrap',
#  'tebal',
#  'thank',
#  'you',
#  'seller',
#  'sampai',
#  'dah',
#  'yay',
#  'thank',
#  'you',
#  'seller',
#  'banyak',
#  'kali',
#  'dah',
#  'repeat',
#  'veli',
#  'dengan',
#  'seller',
#  'ni',
#  'azhar',
#  'food',
#  'memang',
#  'ter',
#  'baik',
#  'barang',
#  'baik',
#  'sampai',
#  'dengan',
#  'ensem',
#  'seller',
#  'ter',
#  'baik',
#  'packaging',
#  'mantap',
#  'produk',
#  'kacak',
#  'bergaya',
#  'di',
#  'hari',
#  'raya',
#  'delivery',
#  'mantap',
#  'dengan',
#  'pantas',
#  'ter',
#  'baik',
#  'la',
#  'alhamdulillah',
#  'terima',
#  'barang',
#  'dengan',
#  'baik',
#  'dan',
#  'cepat',
#  'penghantaran',
#  'saya',
#  'beli',
#  'ya',
#  'taste',
#  'sedap',
#  'quality',
#  'baik',
#  'thank',
#  'you',
#  'seller',
#  'barang',
#  'dah',
#  'sampai',
#  'dengan',
#  'selamat',
#  'wah',
#  'packing',
#  'kemas',
#  'betul',
#  'memang',
#  'bagus',
#  'la',
#  'seller',
#  'ni',
#  'siap',
#  'bub',
#  'la',
#  'tebal',
#  'lagi',
#  'ter',
#  'baik',
#  'la',
#  'alhamdulillah',
#  'kacang',
#  'pun',
#  'sedap',
#  'dah',
#  'banyak',
#  'kali',
#  'oder',
#  'dari',
#  'seller',
#  'ni',
#  'harga',
#  'paling',
#  'murah',
#  'dari',
#  'seller',
#  'lain',
#  'bungkuih',
#  'elok',
#  'tak',
#  'hancur',
#  'kuih',
#  'siput',
#  'besar',
#  'gedabak',
#  'puas',
#  'hati',
#  'kacang',
#  'pilus',
#  'pun',
#  'puas',
#  'hati',
#  'pek',
#  'besar',
#  'la',
#  'buat',
#  'kudap',
#  'kudap',
#  'packaging',
#  'ok',
#  'kerepek',
#  'tak',
#  'hancur',
#  'sangat',
#  'tapi',
#  'tak',
#  'sempat',
#  'nak',
#  'rasa',
#  'lagi',
#  'service',
#  'recomended',
#  'kuih',
#  'paling',
#  'mak',
#  'sister',
#  'suka',
#  'favorite',
#  'ni',
#  'shiping',
#  'pun',
#  'cepat',
#  'sampai',
#  'kuih',
#  'siput',
#  'sedap',
#  'sangat',
#  'really',
#  'recomended',
#  'kena',
#  'try',
#  'barang',
#  'dah',
#  'sampai',
#  'tapi',
#  'kopok',
#  'jagung',
#  'pilus',
#  'ada',
#  'semut',
#  'sikit',
#  'tak',
#  'ntau',
#  'dari',
#  'mana',
#  'datang',
#  'tapi',
#  'tak',
#  'apa',
#  'tak',
#  'masuk',
#  ...]

# %%
print(len(all_words_lista))
# Out:
# 13785

# %%
def flatten(l):
    return [item for sublist in l for item in sublist]
all_words_listb = flatten(docs)
all_words_listc #contains all words from both classes
# Out:
# ['sedap',
#  'taste',
#  'sedap',
#  'rasa',
#  'coklat',
#  'semua',
#  'cukup',
#  'quality',
#  'good',
#  'quality',
#  'baik',
#  'taste',
#  'sedap',
#  'belikan',
#  'untuk',
#  'adik',
#  'yang',
#  'mengidam',
#  'sangat',
#  'nak',
#  'batang',
#  'buruk',
#  'tawakal',
#  'saja',
#  'beli',
#  'ni',
#  'masa',
#  'itu',
#  'tak',
#  'sangka',
#  'adik',
#  'cakap',
#  'sedap',
#  'kita',
#  'pula',
#  'tertelan',
#  'air',
#  'liur',
#  'haha',
#  'kena',
#  'beli',
#  'juga',
#  'nanti',
#  'untuk',
#  'diri',
#  'pula',
#  'ni',
#  'alhamdulillah',
#  'sampai',
#  'dah',
#  'sedap',
#  'tapi',
#  'hancur',
#  'kena',
#  'pakai',
#  'sudu',
#  'makan',
#  'padan',
#  'la',
#  'beli',
#  'time',
#  'shocking',
#  'sale',
#  'bungkusan',
#  'selamat',
#  'tak',
#  'dak',
#  'pecah',
#  'dah',
#  'banyak',
#  'kali',
#  'repeat',
#  'memang',
#  'tor',
#  'baik',
#  'alhamdulillah',
#  'sedap',
#  'sangat',
#  'sangat',
#  'beli',
#  'la',
#  'jangan',
#  'ragu',
#  'lagi',
#  'sampai',
#  'dengan',
#  'selamat',
#  'repeat',
#  'order',
#  'berkali',
#  'sudah',
#  'terima',
#  'kasih',
#  'thank',
#  'you',
#  'barang',
#  'baru',
#  'saja',
#  'dterima',
#  'wah',
#  'bekas',
#  'yang',
#  'bagus',
#  'tak',
#  'mudah',
#  'pecah',
#  'thank',
#  'you',
#  'sekali',
#  'lagi',
#  'pada',
#  'seller',
#  'mengambil',
#  'perhatian',
#  'atas',
#  'komen',
#  'saya',
#  'terdahulu',
#  'batang',
#  'buruk',
#  'really',
#  'marvellous',
#  'sedap',
#  'sangat',
#  'ter',
#  'baik',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'pergi',
#  'memang',
#  'sedap',
#  'ha',
#  'rugi',
#  'hangpa',
#  'dak',
#  'beli',
#  'oi',
#  'sedap',
#  'tak',
#  'boleh',
#  'dibawa',
#  'bincang',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'items',
#  'safely',
#  'arived',
#  'not',
#  'taste',
#  'yet',
#  'hopefully',
#  'good',
#  'haha',
#  'thank',
#  'you',
#  'lot',
#  'seller',
#  'for',
#  'following',
#  'up',
#  'the',
#  'tracking',
#  'itesm',
#  'rasa',
#  'sedap',
#  'dan',
#  'rangup',
#  'kuih',
#  'rasa',
#  'fresh',
#  'dan',
#  'tak',
#  'rasa',
#  'lama',
#  'packaging',
#  'kemas',
#  'berbaloi',
#  'beli',
#  'walaupun',
#  'harga',
#  'agak',
#  'mahal',
#  'berbanding',
#  'yang',
#  'lain',
#  'kualiti',
#  'terima',
#  'kasih',
#  'seller',
#  'saya',
#  'beli',
#  'delivery',
#  'sangat',
#  'cepat',
#  'and',
#  'packaging',
#  'bagus',
#  'yang',
#  'penting',
#  'rasa',
#  'sangat',
#  'sedap',
#  'parents',
#  'pun',
#  'suka',
#  'terus',
#  'masuk',
#  'botol',
#  'buat',
#  'snacks',
#  'boleh',
#  'repeat',
#  'order',
#  'nanti',
#  'thank',
#  'you',
#  'you',
#  'rasa',
#  'ok',
#  'tapi',
#  'kalau',
#  'lagi',
#  'ranggup',
#  'lagi',
#  'sedap',
#  'overal',
#  'ok',
#  'peratusan',
#  'hancur',
#  'tak',
#  'banyak',
#  'sangat',
#  'boleh',
#  'makan',
#  'la',
#  'tapi',
#  'pernah',
#  'rasa',
#  'lagi',
#  'yang',
#  'betul',
#  'sedap',
#  'nak',
#  'sangat',
#  'cari',
#  'yang',
#  'rasa',
#  'kacang',
#  'hijau',
#  'tapi',
#  'tak',
#  'dapat',
#  'so',
#  'far',
#  'yang',
#  'ni',
#  'garing',
#  'la',
#  'sedap',
#  'juga',
#  'taste',
#  'good',
#  'quality',
#  'good',
#  'nasib',
#  'baik',
#  'tak',
#  'hancur',
#  'jadi',
#  'sagun',
#  'bila',
#  'terperap',
#  'lama',
#  'di',
#  'hub',
#  'quality',
#  'baik',
#  'taste',
#  'sedap',
#  'belikan',
#  'untuk',
#  'adik',
#  'yang',
#  'mengidam',
#  'sangat',
#  'nak',
#  'batang',
#  'buruk',
#  'tawakal',
#  'saja',
#  'beli',
#  'ni',
#  'masa',
#  'itu',
#  'tak',
#  'sangka',
#  'adik',
#  'cakap',
#  'sedap',
#  'kita',
#  'pula',
#  'tertelan',
#  'air',
#  'liur',
#  'haha',
#  'kena',
#  'beli',
#  'juga',
#  'nanti',
#  'untuk',
#  'diri',
#  'pula',
#  'ni',
#  'alhamdulillah',
#  'sampai',
#  'dah',
#  'sedap',
#  'tapi',
#  'hancur',
#  'kena',
#  'pakai',
#  'sudu',
#  'makan',
#  'padan',
#  'la',
#  'beli',
#  'time',
#  'shocking',
#  'sale',
#  'bungkusan',
#  'selamat',
#  'tak',
#  'dak',
#  'pecah',
#  'dah',
#  'banyak',
#  'kali',
#  'repeat',
#  'memang',
#  'tor',
#  'baik',
#  'alhamdulillah',
#  'sedap',
#  'sangat',
#  'sangat',
#  'beli',
#  'la',
#  'jangan',
#  'ragu',
#  'lagi',
#  'sampai',
#  'dengan',
#  'selamat',
#  'repeat',
#  'order',
#  'berkali',
#  'sudah',
#  'terima',
#  'kasih',
#  'thank',
#  'you',
#  'barang',
#  'baru',
#  'saja',
#  'dterima',
#  'wah',
#  'bekas',
#  'yang',
#  'bagus',
#  'tak',
#  'mudah',
#  'pecah',
#  'thank',
#  'you',
#  'sekali',
#  'lagi',
#  'pada',
#  'seller',
#  'mengambil',
#  'perhatian',
#  'atas',
#  'komen',
#  'saya',
#  'terdahulu',
#  'batang',
#  'buruk',
#  'really',
#  'marvellous',
#  'sedap',
#  'sangat',
#  'ter',
#  'baik',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'good',
#  'pergi',
#  'memang',
#  'sedap',
#  'ha',
#  'rugi',
#  'hangpa',
#  'dak',
#  'beli',
#  'oi',
#  'sedap',
#  'tak',
#  'boleh',
#  'dibawa',
#  'bincang',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'ter',
#  'baik',
#  'alhamdulillah',
#  'parcel',
#  'selamat',
#  'sampai',
#  'kejap',
#  'time',
#  'beli',
#  'dari',
#  'seller',
#  'harap',
#  'memuaskan',
#  'thank',
#  'you',
#  'seller',
#  'quality',
#  'ok',
#  'taste',
#  'ok',
#  'penghantaran',
#  'cepat',
#  'barang',
#  'dibalut',
#  'dengan',
#  'bub',
#  'la',
#  'wrap',
#  'rasa',
#  'ok',
#  'tak',
#  'berapa',
#  'kuat',
#  'biasa',
#  'saja',
#  'delivery',
#  'laju',
#  'bethol',
#  'kerepek',
#  'sedap',
#  'gila',
#  'boleh',
#  'makan',
#  'sambil',
#  'tengok',
#  'cerita',
#  'cukup',
#  'derita',
#  'itu',
#  'hehe',
#  'ok',
#  'alhamdulillah',
#  'kuih',
#  'sedap',
#  'rangup',
#  'sedang',
#  'penuh',
#  'flavour',
#  'saya',
#  'suka',
#  'harga',
#  'sangat',
#  'berpatutan',
#  'tqtqtq',
#  'tqtqtq',
#  'tqtqtq',
#  'tqtqtq',
#  'tqtqtq',
#  'tqtqtq',
#  'tqtqtq',
#  'taste',
#  'sedap',
#  'sungguh',
#  'quality',
#  'not',
#  'bad',
#  'yum',
#  'yum',
#  'yum',
#  'kuih',
#  'siput',
#  'selamat',
#  'diterima',
#  'dalam',
#  'bungkusan',
#  'yang',
#  'kemas',
#  'rasa',
#  'pun',
#  'sedap',
#  'terima',
#  'kasih',
#  'seller',
#  'ok',
#  'sedap',
#  'rangup',
#  'cepat',
#  'juga',
#  'pos',
#  'packaging',
#  'pun',
#  'ok',
#  'kotak',
#  'kemek',
#  'sikit',
#  'tapi',
#  'dalam',
#  'ok',
#  'dah',
#  'berapa',
#  'kali',
#  'repeat',
#  'dah',
#  'thank',
#  'you',
#  'seller',
#  'aku',
#  'beli',
#  'sedap',
#  'seller',
#  'pos',
#  'cepat',
#  'barang',
#  'tapi',
#  'ninja',
#  'van',
#  'la',
#  'thank',
#  'you',
#  'seller',
#  'taste',
#  'sedap',
#  'quality',
#  'baik',
#  'barang',
#  'diterima',
#  'dalam',
#  'keadaan',
#  'baik',
#  'penghantaran',
#  'pantas',
#  'kuih',
#  'siput',
#  'pun',
#  'sedap',
#  'sangat',
#  'taste',
#  'sedap',
#  'rangup',
#  'quality',
#  'baik',
#  'penghantaran',
#  'pantas',
#  'barang',
#  'diterima',
#  'dalam',
#  'keadaan',
#  'baik',
#  'kuih',
#  'siput',
#  'pun',
#  'sedap',
#  'ter',
#  'baik',
#  'terima',
#  'kasih',
#  'seller',
#  'barang',
#  'sudah',
#  'diterima',
#  'terima',
#  'kasih',
#  'seller',
#  'saya',
#  'beli',
#  'ya',
#  'penghantaran',
#  'super',
#  'laju',
#  'bungkusan',
#  'ter',
#  'baik',
#  'bub',
#  'la',
#  'wrap',
#  'tebal',
#  'thank',
#  'you',
#  'seller',
#  'sampai',
#  'dah',
#  'yay',
#  'thank',
#  'you',
#  'seller',
#  'banyak',
#  'kali',
#  'dah',
#  'repeat',
#  'veli',
#  'dengan',
#  'seller',
#  'ni',
#  'azhar',
#  'food',
#  'memang',
#  'ter',
#  'baik',
#  'barang',
#  'baik',
#  'sampai',
#  'dengan',
#  'ensem',
#  'seller',
#  'ter',
#  'baik',
#  'packaging',
#  'mantap',
#  'produk',
#  'kacak',
#  'bergaya',
#  'di',
#  'hari',
#  'raya',
#  'delivery',
#  'mantap',
#  'dengan',
#  'pantas',
#  'ter',
#  'baik',
#  'la',
#  'alhamdulillah',
#  'terima',
#  'barang',
#  'dengan',
#  'baik',
#  'dan',
#  'cepat',
#  'penghantaran',
#  'saya',
#  'beli',
#  'ya',
#  'taste',
#  'sedap',
#  'quality',
#  'baik',
#  'thank',
#  'you',
#  'seller',
#  'barang',
#  'dah',
#  'sampai',
#  'dengan',
#  'selamat',
#  'wah',
#  'packing',
#  'kemas',
#  'betul',
#  'memang',
#  'bagus',
#  'la',
#  'seller',
#  'ni',
#  'siap',
#  'bub',
#  'la',
#  'tebal',
#  'lagi',
#  'ter',
#  'baik',
#  'la',
#  'alhamdulillah',
#  'kacang',
#  'pun',
#  'sedap',
#  'dah',
#  'banyak',
#  'kali',
#  'oder',
#  'dari',
#  'seller',
#  'ni',
#  'harga',
#  'paling',
#  'murah',
#  'dari',
#  'seller',
#  'lain',
#  'bungkuih',
#  'elok',
#  'tak',
#  'hancur',
#  'kuih',
#  'siput',
#  'besar',
#  'gedabak',
#  'puas',
#  'hati',
#  'kacang',
#  'pilus',
#  'pun',
#  'puas',
#  'hati',
#  'pek',
#  'besar',
#  'la',
#  'buat',
#  'kudap',
#  'kudap',
#  'packaging',
#  'ok',
#  'kerepek',
#  'tak',
#  'hancur',
#  'sangat',
#  'tapi',
#  'tak',
#  'sempat',
#  'nak',
#  'rasa',
#  'lagi',
#  'service',
#  'recomended',
#  'kuih',
#  'paling',
#  'mak',
#  'sister',
#  'suka',
#  'favorite',
#  'ni',
#  'shiping',
#  'pun',
#  'cepat',
#  'sampai',
#  'kuih',
#  'siput',
#  'sedap',
#  'sangat',
#  'really',
#  'recomended',
#  'kena',
#  'try',
#  'barang',
#  'dah',
#  'sampai',
#  'tapi',
#  'kopok',
#  'jagung',
#  'pilus',
#  'ada',
#  'semut',
#  'sikit',
#  'tak',
#  'ntau',
#  'dari',
#  'mana',
#  'datang',
#  'tapi',
#  'tak',
#  'apa',
#  'tak',
#  'masuk',
#  ...]

# %%
print(len(all_words_listb))

# %%
#calculate the unique word with its frequency from both class of sentiment --> count (w)
word_freq=[all_words_list.count(p) for p in all_words_list]
all_word_dict = dict(zip(all_words_list,word_freq)) # this create dictionary of unique word and its frequency

# %%
sort_all_word_dict =  OrderedDict(sorted(all_word_dict.items()))
sort_all_word_dict #final output from descending order aplhabetically
# Out:
# OrderedDict([('', 1),
#              ('abang', 2),
#              ('abeh', 1),
#              ('actually', 2),
#              ('acuh', 2),
#              ('ada', 111),
#              ('adik', 5),
#              ('adjust', 1),
#              ('adooi', 1),
#              ('adoyai', 1),
#              ('after', 1),
#              ('again', 8),
#              ('agak', 51),
#              ('agar', 1),
#              ('agent', 1),
#              ('agr', 1),
#              ('air', 3),
#              ('ais', 1),
#              ('aje', 7),
#              ('akan', 16),
#              ('akhir', 3),
#              ('akhirat', 1),
#              ('aktiviti', 1),
#              ('aku', 6),
#              ('alamat', 1),
#              ('alangkah', 1),
#              ('alhamdulillah', 66),
#              ('alhamdullilah', 2),
#              ('alhmdulillah', 1),
#              ('all', 4),
#              ('allah', 6),
#              ('already', 1),
#              ('also', 2),
#              ('always', 1),
#              ('amat', 2),
#              ('ambil', 10),
#              ('amin', 2),
#              ('amt', 1),
#              ('amualaikum', 2),
#              ('anak', 8),
#              ('and', 30),
#              ('anda', 2),
#              ('angin', 5),
#              ('antara', 1),
#              ('any', 1),
#              ('anyway', 5),
#              ('apa', 41),
#              ('apepn', 1),
#              ('apepon', 1),
#              ('apepun', 5),
#              ('aplikasi', 1),
#              ('are', 2),
#              ('arive', 1),
#              ('arived', 5),
#              ('arkan', 1),
#              ('around', 1),
#              ('art', 2),
#              ('as', 5),
#              ('asal', 5),
#              ('asam', 4),
#              ('asap', 1),
#              ('at', 3),
#              ('atas', 6),
#              ('atau', 4),
#              ('au', 1),
#              ('aum', 1),
#              ('awak', 1),
#              ('awal', 1),
#              ('awesome', 1),
#              ('azhar', 4),
#              ('azharfood', 1),
#              ('azu', 1),
#              ('baca', 1),
#              ('bad', 7),
#              ('bagai', 1),
#              ('bagi', 41),
#              ('bagitahu', 1),
#              ('bagus', 44),
#              ('baha', 1),
#              ('bahagian', 2),
#              ('bahalu', 1),
#              ('bahasa', 1),
#              ('bahulu', 15),
#              ('baik', 282),
#              ('baiki', 1),
#              ('bajet', 1),
#              ('baju', 2),
#              ('balang', 11),
#              ('balas', 1),
#              ('balerbaloi', 1),
#              ('balik', 6),
#              ('baling', 4),
#              ('baloi', 1),
#              ('balut', 7),
#              ('balutan', 3),
#              ('bangkit', 3),
#              ('bantat', 1),
#              ('banyak', 53),
#              ('banyakan', 1),
#              ('banyka', 1),
#              ('barang', 151),
#              ('baru', 19),
#              ('basah', 5),
#              ('based', 1),
#              ('batang', 10),
#              ('batik', 1),
#              ('batu', 1),
#              ('bau', 3),
#              ('baulu', 2),
#              ('bawah', 3),
#              ('bawang', 8),
#              ('bayar', 1),
#              ('be', 2),
#              ('bean', 1),
#              ('because', 1),
#              ('before', 1),
#              ('beg', 1),
#              ('begini', 1),
#              ('begitu', 4),
#              ('bekang', 1),
#              ('bekas', 20),
#              ('beli', 112),
#              ('belikan', 3),
#              ('belimbing', 1),
#              ('belum', 27),
#              ('benda', 1),
#              ('bentuk', 1),
#              ('beranak', 1),
#              ('berapa', 13),
#              ('berat', 1),
#              ('berbaloi', 18),
#              ('berbanding', 2),
#              ('berbuas', 1),
#              ('berbuka', 4),
#              ('berderai', 1),
#              ('berempah', 1),
#              ('bergaya', 1),
#              ('bergerak', 1),
#              ('bergoncang', 1),
#              ('berhari', 2),
#              ('berhati', 1),
#              ('berhenti', 6),
#              ('beri', 1),
#              ('beritahu', 1),
#              ('berkali', 3),
#              ('berkenaan', 3),
#              ('berketul', 1),
#              ('berkualati', 1),
#              ('berkualiti', 1),
#              ('berkulat', 1),
#              ('berkuliti', 1),
#              ('berlapis', 1),
#              ('berlubang', 1),
#              ('bermanfaat', 1),
#              ('berminat', 1),
#              ('berminggu', 1),
#              ('berminyak', 5),
#              ('berpadanan', 1),
#              ('berpatutan', 3),
#              ('berpe', 1),
#              ('berpuas', 6),
#              ('berpuasa', 2),
#              ('bersama', 2),
#              ('bersih', 1),
#              ('bertanggungjwb', 2),
#              ('bertekstur', 1),
#              ('berterabur', 1),
#              ('berurusan', 2),
#              ('beryl', 1),
#              ('besar', 8),
#              ('best', 9),
#              ('bethol', 1),
#              ('better', 3),
#              ('betul', 12),
#              ('bggian', 1),
#              ('bgkusan', 2),
#              ('bgth', 1),
#              ('bhgn', 1),
#              ('biar', 1),
#              ('biasa', 45),
#              ('biaskut', 1),
#              ('big', 1),
#              ('bila', 15),
#              ('bilis', 9),
#              ('bincang', 3),
#              ('bintang', 16),
#              ('birokrasi', 1),
#              ('birthday', 2),
#              ('biskut', 16),
#              ('bismillah', 1),
#              ('bisnis', 1),
#              ('bit', 7),
#              ('blis', 1),
#              ('blouse', 1),
#              ('bls', 1),
#              ('bly', 1),
#              ('bngkit', 1),
#              ('bngkusan', 2),
#              ('bocor', 4),
#              ('boh', 2),
#              ('bola', 2),
#              ('boleh', 103),
#              ('bolh', 1),
#              ('bolih', 1),
#              ('borong', 2),
#              ('bos', 1),
#              ('bot', 1),
#              ('botol', 12),
#              ('box', 3),
#              ('bpuasa', 1),
#              ('brand', 2),
#              ('broke', 1),
#              ('bronice', 1),
#              ('brooch', 1),
#              ('brownies', 1),
#              ('bsnes', 1),
#              ('btng', 1),
#              ('buah', 15),
#              ('buahan', 1),
#              ('buang', 1),
#              ('buat', 16),
#              ('bub', 44),
#              ('bubles', 1),
#              ('bublewrap', 4),
#              ('bubuh', 1),
#              ('bucu', 1),
#              ('budi', 1),
#              ('buka', 7),
#              ('bukan', 18),
#              ('bulan', 6),
#              ('bun', 1),
#              ('buncit', 1),
#              ('bund', 2),
#              ('bunga', 1),
#              ('bungkuih', 1),
#              ('bungkus', 14),
#              ('bungkusan', 28),
#              ('burb', 1),
#              ('buruk', 10),
#              ('busines', 1),
#              ('but', 22),
#              ('buter', 4),
#              ('buterscotch', 2),
#              ('buy', 3),
#              ('buyer', 2),
#              ('bwg', 2),
#              ('by', 10),
#              ('cadangkan', 1),
#              ('cair', 4),
#              ('cakap', 7),
#              ('cake', 3),
#              ('campak', 3),
#              ('can', 3),
#              ('cantek', 1),
#              ('cantik', 4),
#              ('cara', 4),
#              ('card', 2),
#              ('cari', 2),
#              ('carot', 1),
#              ('cawan', 1),
#              ('cedok', 1),
#              ('cek', 2),
#              ('celebrate', 1),
#              ('cemane', 1),
#              ('cepat', 83),
#              ('cerita', 2),
#              ('cermai', 3),
#              ('cermat', 3),
#              ('certain', 2),
#              ('chat', 3),
#              ('che', 3),
#              ('check', 3),
#              ('cheese', 6),
#              ('chenor', 1),
#              ('chiang', 2),
#              ('chiangrai', 2),
#              ('chinese', 1),
#              ('chips', 2),
#              ('choc', 1),
#              ('choco', 1),
#              ('chocojar', 3),
#              ('chocojarleleh', 1),
#              ('choice', 1),
#              ('chrunchy', 1),
#              ('churn', 1),
#              ('cibai', 1),
#              ('cili', 2),
#              ('cincang', 2),
#              ('cincin', 1),
#              ('citarasa', 6),
#              ('citerasa', 1),
#              ('ckit', 3),
#              ('class', 2),
#              ('cmpk', 1),
#              ('cococrunch', 1),
#              ('cod', 1),
#              ('coin', 1),
#              ('coklat', 12),
#              ('cokletjar', 1),
#              ('colet', 1),
#              ('collect', 2),
#              ('collector', 2),
#              ('comel', 2),
#              ('compare', 1),
#              ('condition', 2),
#              ('confirm', 2),
#              ('container', 2),
#              ('cookies', 1),
#              ('could', 1),
#              ('courier', 7),
#              ('crack', 1),
#              ('cracked', 1),
#              ('craving', 3),
#              ('crispy', 1),
#              ('crpat', 1),
#              ('crunch', 1),
#              ('crunchy', 6),
#              ('ct', 1),
#              ('cuba', 11),
#              ('cuci', 1),
#              ('cukup', 17),
#              ('cuma', 68),
#              ('cun', 1),
#              ('cup', 2),
#              ('curier', 1),
#              ('customer', 6),
#              ('cuting', 1),
#              ('daging', 2),
#              ('dagingrepeat', 1),
#              ('dah', 184),
#              ('dail', 1),
#              ('dak', 5),
#              ('dalam', 106),
#              ('damage', 1),
#              ('damaged', 1),
#              ('dan', 138),
#              ('dapat', 44),
#              ('dari', 43),
#              ('daripada', 4),
#              ('datang', 10),
#              ('day', 1),
#              ('days', 2),
#              ('dbndingkan', 1),
#              ('dealer', 1),
#              ('dec', 1),
#              ('definitely', 2),
#              ('dekat', 25),
#              ('delay', 1),
#              ('delicious', 1),
#              ('delivary', 1),
#              ('deliver', 2),
#              ('delivery', 39),
#              ('dendeng', 2),
#              ('dengan', 132),
#              ('dengn', 1),
#              ('dengna', 1),
#              ('depan', 1),
#              ('deram', 8),
#              ('derita', 1),
#              ('dha', 1),
#              ('di', 32),
#              ('dia', 59),
#              ('diaktifkan', 1),
#              ('diakui', 2),
#              ('dibaiki', 1),
#              ('dibalut', 6),
#              ('dibawa', 2),
#              ('dibayangkan', 1),
#              ('dibeli', 1),
#              ('diberikan', 2),
#              ('dibuat', 1),
#              ('dibungkus', 7),
#              ('dicadangkan', 1),
#              ('did', 1),
#              ('didalam', 4),
#              ('didlm', 1),
#              ('didn', 1),
#              ('dif', 1),
#              ('difahami', 1),
#              ('digalakan', 1),
#              ('dihantar', 2),
#              ('dihidangkan', 1),
#              ('dikatakan', 1),
#              ('diletak', 1),
#              ('diluar', 2),
#              ('dimakan', 6),
#              ('dimasukan', 2),
#              ('dimulut', 1),
#              ('dimurahkan', 2),
#              ('dipek', 3),
#              ('diperbaiki', 3),
#              ('dipesan', 1),
#              ('direview', 1),
#              ('diri', 2),
#              ('disapointed', 3),
#              ('disapoints', 1),
#              ('disarankan', 1),
#              ('disebabkan', 3),
#              ('diselitkan', 1),
#              ('disi', 1),
#              ('disiplin', 1),
#              ('diterima', 30),
#              ('ditmbh', 1),
#              ('dng', 3),
#              ('doakan', 1),
#              ('dok', 2),
#              ('doorgift', 1),
#              ('dos', 1),
#              ('doub', 1),
#              ('dry', 1),
#              ('dterima', 2),
#              ('dtrima', 1),
#              ('dua', 10),
#              ('duber', 1),
#              ('due', 2),
#              ('duit', 5),
#              ('dulu', 14),
#              ('dunia', 1),
#              ('ea', 1),
#              ('eatab', 1),
#              ('edit', 1),
#              ('efficient', 2),
#              ('effort', 1),
#              ('eggyolk', 2),
#              ('ekspres', 1),
#              ('elakan', 1),
#              ('elemen', 1),
#              ('elok', 39),
#              ('empat', 2),
#              ('emping', 1),
#              ('enak', 1),
#              ('enough', 1),
#              ('ensem', 1),
#              ('entah', 3),
#              ('erm', 1),
#              ('es', 2),
#              ('esok', 3),
#              ('even', 2),
#              ('eventho', 1),
#              ('everything', 1),
#              ('excellent', 2),
#              ('exp', 2),
#              ('expect', 1),
#              ('expectation', 4),
#              ('expected', 1),
#              ('expired', 4),
#              ('expreas', 1),
#              ('extra', 2),
#              ('faktor', 1),
#              ('family', 3),
#              ('far', 5),
#              ('fast', 26),
#              ('fastshiping', 1),
#              ('favorite', 1),
#              ('fine', 2),
#              ('first', 5),
#              ('fisikal', 1),
#              ('flavour', 1),
#              ('florentine', 1),
#              ('foam', 1),
#              ('follow', 1),
#              ('following', 1),
#              ('food', 4),
#              ('for', 19),
#              ('founder', 1),
#              ('fra', 9),
#              ('free', 12),
#              ('fresh', 2),
#              ('friendly', 2),
#              ('from', 2),
#              ('fruits', 1),
#              ('future', 1),
#              ('gamak', 2),
#              ('gambar', 8),
#              ('gambr', 1),
#              ('ganas', 1),
#              ('ganti', 2),
#              ('gantikan', 2),
#              ('gara', 1),
#              ('garing', 4),
#              ('gateway', 1),
#              ('gebu', 3),
#              ('gedabak', 1),
#              ('gemuk', 5),
#              ('gemuks', 1),
#              ('gerobok', 1),
#              ('gesek', 1),
#              ('get', 2),
#              ('gift', 5),
#              ('gigi', 3),
#              ('gigih', 1),
#              ('gigit', 1),
#              ('gila', 22),
#              ('giller', 1),
#              ('gituw', 1),
#              ('give', 2),
#              ('gladly', 1),
#              ('gm', 1),
#              ('gmbo', 1),
#              ('god', 1),
#              ('gold', 1),
#              ('gona', 1),
#              ('good', 137),
#              ('goodjob', 1),
#              ('goods', 1),
#              ('goreng', 1),
#              ('got', 3),
#              ('gud', 1),
#              ('gula', 5),
#              ('gulung', 3),
#              ('guna', 10),
#              ('gunakan', 1),
#              ('ha', 2),
#              ('habis', 17),
#              ('habuk', 2),
#              ('had', 1),
#              ('hadiah', 2),
#              ('haha', 17),
#              ('haih', 1),
#              ('hal', 1),
#              ('halal', 1),
#              ('halalkan', 2),
#              ('halia', 1),
#              ('halus', 1),
#              ('hampas', 1),
#              ('hampir', 4),
#              ('hancur', 91),
#              ('hancus', 1),
#              ('hand', 1),
#              ('handling', 1),
#              ('hangit', 4),
#              ('hangpa', 2),
#              ('hangus', 1),
#              ('hani', 1),
#              ('hantar', 9),
#              ('hantaran', 1),
#              ('hanyir', 2),
#              ('hapak', 1),
#              ('happy', 2),
#              ('harap', 32),
#              ('harda', 1),
#              ('harga', 36),
#              ('hari', 53),
#              ('harm', 1),
#              ('hati', 41),
#              ('have', 1),
#              ('hb', 2),
#              ('heavy', 1),
#              ('hehe', 5),
#              ('high', 4),
#              ('hihi', 2),
#              ('hijau', 2),
#              ('hilang', 2),
#              ('hitam', 12),
#              ('hm', 1),
#              ('hncur', 3),
#              ('hndakne', 1),
#              ('home', 1),
#              ('honest', 1),
#              ('hope', 3),
#              ('hopefully', 3),
#              ('hotlink', 1),
#              ('however', 1),
#              ('hrpw', 1),
#              ('hrs', 1),
#              ('hti', 2),
#              ('htr', 1),
#              ('hu', 1),
#              ('hub', 2),
#              ('huhu', 4),
#              ('hujan', 2),
#              ('hujung', 1),
#              ('hurm', 1),
#              ('ibu', 1),
#              ('ikan', 9),
#              ('iklan', 2),
#              ('ikut', 1),
#              ('ilmu', 1),
#              ('impresed', 1),
#              ('improve', 11),
#              ('improved', 1),
#              ('improving', 1),
#              ('improvise', 1),
#              ('in', 10),
#              ('indah', 1),
#              ('iner', 1),
#              ('ingat', 4),
#              ('ingatkan', 2),
#              ('ini', 15),
#              ('insha', 1),
#              ('inshaaallah', 2),
#              ('inside', 2),
#              ('instant', 1),
#              ('insya', 2),
#              ('insyaallah', 4),
#              ('insyallah', 1),
#              ('internet', 2),
#              ('inti', 27),
#              ('into', 1),
#              ('is', 11),
#              ('isi', 6),
#              ('isik', 1),
#              ('isnin', 1),
#              ('isteri', 2),
#              ('it', 11),
#              ('item', 18),
#              ('items', 4),
#              ('itesm', 1),
#              ('its', 1),
#              ('itself', 1),
#              ('itu', 66),
#              ('jadi', 13),
#              ('jaga', 2),
#              ('jagung', 2),
#              ('jahanam', 1),
#              ('jamu', 1),
#              ('jangan', 8),
#              ('janji', 1),
#              ('jar', 2),
#              ('jatuh', 1),
#              ('jauh', 7),
#              ('jawa', 1),
#              ('jaya', 4),
#              ('jdikan', 1),
#              ('jeedjard', 1),
#              ('jejari', 1),
#              ('jem', 3),
#              ('jemput', 2),
#              ('jenama', 1),
#              ('jenis', 1),
#              ('jet', 1),
#              ('jika', 2),
#              ('jiran', 1),
#              ('jnjy', 1),
#              ('jnt', 7),
#              ('job', 7),
#              ('jual', 5),
#              ('juga', 52),
#              ('jugk', 1),
#              ('jujur', 4),
#              ('jumaat', 2),
#              ('jumpa', 2),
#              ('just', 9),
#              ('kacak', 1),
#              ('kacang', 3),
#              ('kadbod', 2),
#              ('kaitan', 3),
#              ('kakak', 3),
#              ('kalau', 46),
#              ('kalender', 1),
#              ('kali', 61),
#              ('kami', 1),
#              ('kampung', 6),
#              ('kan', 16),
#              ('kapit', 2),
#              ('kari', 1),
#              ('karipap', 14),
#              ('kasar', 4),
#              ('kaseh', 1),
#              ('kasih', 67),
#              ('kasug', 1),
#              ('kat', 23),
#              ('kata', 5),
#              ('kawal', 1),
#              ('kawan', 2),
#              ('kawasan', 1),
#              ('kaya', 1),
#              ('kcg', 1),
#              ('ke', 29),
#              ('keadaaan', 1),
#              ('keadaan', 56),
#              ('kebaikan', 1),
#              ('kebetulan', 2),
#              ('kecewa', 5),
#              ('kecil', 16),
#              ('kecuaian', 1),
#              ('kecuali', 1),
#              ('kedah', 1),
#              ('kedai', 5),
#              ('kedekut', 2),
#              ('kedua', 14),
#              ('keep', 3),
#              ('keesokan', 1),
#              ('kegemaran', 2),
#              ('kegemaranku', 1),
#              ('kejap', 12),
#              ('kek', 63),
#              ('kekalkan', 2),
#              ('kelantan', 2),
#              ('kelapa', 1),
#              ('kelihatan', 1),
#              ('kelonggaran', 1),
#              ('keluar', 7),
#              ('keluarga', 1),
#              ('kemas', 42),
#              ('kemasan', 2),
#              ('kembung', 1),
#              ('kemek', 11),
#              ('kemik', 3),
#              ('kemudian', 2),
#              ('kena', 48),
#              ('kencing', 1),
#              ('kentang', 3),
#              ('kepek', 1),
#              ('keping', 1),
#              ('kerana', 8),
#              ('kerangupan', 1),
#              ('keras', 26),
#              ('kerenah', 1),
#              ('kerepek', 48),
#              ('kerepk', 5),
#              ('kerepok', 1),
#              ('kering', 9),
#              ('kerja', 2),
#              ('keropok', 6),
#              ('kerosakan', 2),
#              ('kerusi', 1),
#              ('kesan', 1),
#              ('kesehatan', 1),
#              ('kesesuaian', 1),
#              ('kesilapan', 1),
#              ('kesukaan', 1),
#              ('ketat', 2),
#              ('ketiga', 1),
#              ('ketika', 1),
#              ('khamis', 1),
#              ('kinderbueno', 1),
#              ('kira', 6),
#              ('kisah', 2),
#              ('kismis', 1),
#              ('kita', 8),
#              ('kiuh', 1),
#              ('klik', 1),
#              ('komen', 4),
#              ('komponen', 2),
#              ('kondisi', 1),
#              ('kopi', 1),
#              ('kopok', 1),
#              ('korea', 1),
#              ('kot', 11),
#              ('kotak', 37),
#              ('koyak', 2),
#              ('krap', 1),
#              ('kritikal', 1),
#              ('kriuk', 2),
#              ('kropok', 1),
#              ('kruk', 2),
#              ('krup', 1),
#              ('kuala', 1),
#              ('kualiti', 11),
#              ('kuantiti', 2),
#              ('kuarantin', 1),
#              ('kuat', 4),
#              ('kuda', 1),
#              ('kudap', 5),
#              ('kudapan', 6),
#              ('kueh', 2),
#              ('kuih', 73),
#              ('kukus', 2),
#              ('kulat', 3),
#              ('kulit', 6),
#              ('kuning', 1),
#              ('kunyah', 9),
#              ('kuota', 1),
#              ('kurang', 44),
#              ('kurangkan', 4),
#              ('kurg', 1),
#              ('kurier', 3),
#              ('kurung', 1),
#              ('kut', 2),
#              ('la', 220),
#              ('lada', 1),
#              ('ladang', 1),
#              ('lag', 1),
#              ('lagi', 133),
#              ('lain', 48),
#              ('laju', 23),
#              ('lama', 21),
#              ('lambat', 41),
#              ('langsung', 2),
#              ('lapis', 10),
#              ('lapisan', 1),
#              ('lari', 1),
#              ('last', 1),
#              ('late', 1),
#              ('law', 1),
#              ('layak', 1),
#              ('layan', 11),
#              ('layanan', 2),
#              ('layer', 5),
#              ('lazada', 1),
#              ('lbh', 2),
#              ('least', 1),
#              ('lebih', 19),
#              ('lebihkan', 1),
#              ('lekat', 2),
#              ('leleh', 1),
#              ('lemak', 4),
#              ('lemau', 12),
#              ('lembab', 1),
#              ('lembap', 1),
#              ('lembik', 1),
#              ('lembut', 21),
#              ('lencun', 1),
#              ('lengkap', 3),
#              ('lepas', 18),
#              ('letak', 10),
#              ('lewat', 5),
#              ('ley', 2),
#              ('liat', 3),
#              ('licin', 1),
#              ('lid', 1),
#              ('lihat', 1),
#              ('like', 1),
#              ('lima', 1),
#              ('limau', 1),
#              ('list', 1),
#              ('lit', 2),
#              ('liur', 2),
#              ('live', 1),
#              ('lmbut', 1),
#              ('loceng', 1),
#              ('lockdown', 1),
#              ('logically', 1),
#              ('long', 1),
#              ('look', 1),
#              ('loose', 1),
#              ('lori', 1),
#              ('lot', 1),
#              ('love', 1),
#              ('lpis', 1),
#              ('lps', 2),
#              ('ltk', 1),
#              ('luar', 7),
#              ('lubang', 1),
#              ('luih', 1),
#              ('lumpur', 1),
#              ('lunyai', 2),
#              ('lupa', 1),
#              ('lusa', 1),
#              ('maaf', 7),
#              ('mac', 2),
#              ('macam', 57),
#              ('machang', 1),
#              ('made', 1),
#              ('mahal', 5),
#              ('mahupun', 1),
#              ('main', 4),
#              ('maintain', 1),
#              ('maju', 5),
#              ('mak', 9),
#              ('maka', 1),
#              ('makan', 70),
#              ('makanan', 7),
#              ('maklum', 2),
#              ('malam', 3),
#              ('malan', 1),
#              ('malas', 2),
#              ('malaysia', 11),
#              ('malinjo', 1),
#              ('malu', 1),
#              ('mampus', 1),
#              ('man', 1),
#              ('mana', 8),
#              ('manfaatkan', 1),
#              ('manis', 70),
#              ('mantap', 3),
#              ('mantop', 1),
#              ('mantul', 1),
#              ('march', 1),
#              ('marvellous', 3),
#              ('masa', 27),
#              ('masage', 1),
#              ('masak', 2),
#              ('masakan', 1),
#              ('masalah', 5),
#              ('masam', 10),
#              ('masih', 14),
#              ('masin', 11),
#              ('masing', 1),
#              ('masuk', 8),
#              ('masukan', 2),
#              ('mat', 1),
#              ('mata', 1),
#              ('mayb', 1),
#              ('maybe', 11),
#              ('mbps', 1),
#              ('mc', 1),
#              ('mcm', 1),
#              ('mco', 1),
#              ('me', 6),
#              ('meggi', 1),
#              ('meh', 1),
#              ('mei', 1),
#              ('melaka', 1),
#              ('melayu', 1),
#              ('melebihi', 1),
#              ('melekat', 2),
#              ('melekit', 2),
#              ('meleleh', 2),
#              ('melt', 1),
#              ('meluah', 1),
#              ('memang', 77),
#              ('membaling', 1),
#              ('membantu', 1),
#              ('membeli', 1),
#              ('memberi', 1),
#              ('memenuhi', 3),
#              ('memuaskan', 13),
#              ('memudahkan', 1),
#              ('mencari', 1),
#              ('mencuba', 1),
#              ('mencukupi', 2),
#              ('menepati', 2),
#              ('meneram', 1),
#              ('mengadap', 1),
#              ('mengambil', 2),
#              ('mengecewakan', 4),
#              ('mengena', 2),
#              ('menghampakan', 1),
#              ('mengidam', 6),
#              ('mengikut', 1),
#              ('mengun', 3),
#              ('menjadi', 1),
#              ('menjaga', 1),
#              ('menjawab', 1),
#              ('menjual', 2),
#              ('mention', 3),
#              ('menukar', 1),
#              ('menunggu', 1),
#              ('menyambut', 1),
#              ('menyebabkan', 1),
#              ('menyedapkan', 1),
#              ('menyelerakan', 2),
#              ('menyesal', 2),
#              ('merah', 1),
#              ('merasa', 1),
#              ('mertua', 1),
#              ('meruap', 1),
#              ('mesej', 1),
#              ('mesra', 1),
#              ('mesti', 5),
#              ('mgo', 1),
#              ('mh', 1),
#              ('minggu', 7),
#              ('mini', 2),
#              ('minta', 5),
#              ('minuman', 1),
#              ('minyak', 10),
#              ('miri', 1),
#              ('miss', 2),
#              ('mjdi', 1),
#              ('mknan', 2),
#              ('mngidam', 1),
#              ('mnis', 4),
#              ('mnt', 1),
#              ('moga', 1),
#              ('moist', 9),
#              ('molek', 1),
#              ('mom', 2),
#              ('monday', 1),
#              ('money', 3),
#              ('mood', 1),
#              ('mooncake', 1),
#              ('more', 2),
#              ('mouth', 1),
#              ('msg', 1),
#              ('msh', 2),
#              ('msm', 1),
#              ('muak', 2),
#              ('muaskan', 1),
#              ('muat', 1),
#              ('much', 1),
#              ('mudah', 5),
#              ('mujur', 1),
#              ('mula', 3),
#              ('mulut', 3),
#              ('mung', 1),
#              ('mungkin', 22),
#              ('murah', 27),
#              ('musim', 5),
#              ('my', 11),
#              ('myb', 4),
#              ('naik', 3),
#              ('nak', 71),
#              ('nama', 1),
#              ('nampak', 10),
#              ('namun', 1),
#              ('nanti', 37),
#              ('nasib', 19),
#              ('nd', 5),
#              ('nenas', 10),
#              ('never', 1),
#              ('news', 1),
#              ('next', 11),
#              ('ngam', 2),
#              ('ngap', 5),
#              ('ngidam', 1),
#              ('ni', 125),
#              ('niaga', 1),
#              ...])

# %% [markdown]
# ### b. Count frequency of a word, w in each classes --> count(w,pos) and count(w,neg)

# %%
#convert list into dictionary with key as the word, word frequency as the value
docs = tc.SArray(sf_train['text'])
docs_cw = tc.text_analytics.count_words(docs)

# %%
#create count(w, pos)
from collections import OrderedDict

count_wdict_pos = OrderedDict(sorted(docs_cw[0].items())) # index 0 is positive sentiment

# %%
count_wdict_pos
# Out:
# OrderedDict([('abang', 2.0),
#              ('abeh', 1.0),
#              ('actually', 2.0),
#              ('acuh', 2.0),
#              ('ada', 111.0),
#              ('adik', 5.0),
#              ('adjust', 1.0),
#              ('adooi', 1.0),
#              ('adoyai', 1.0),
#              ('after', 1.0),
#              ('again', 8.0),
#              ('agak', 51.0),
#              ('agar', 1.0),
#              ('agent', 1.0),
#              ('agr', 1.0),
#              ('air', 3.0),
#              ('ais', 1.0),
#              ('aje', 7.0),
#              ('akan', 16.0),
#              ('akhir', 3.0),
#              ('akhirat', 1.0),
#              ('aktiviti', 1.0),
#              ('aku', 6.0),
#              ('alamat', 1.0),
#              ('alangkah', 1.0),
#              ('alhamdulillah', 66.0),
#              ('alhamdullilah', 2.0),
#              ('alhmdulillah', 1.0),
#              ('all', 4.0),
#              ('allah', 6.0),
#              ('already', 1.0),
#              ('also', 2.0),
#              ('always', 1.0),
#              ('amat', 2.0),
#              ('ambil', 10.0),
#              ('amin', 2.0),
#              ('amt', 1.0),
#              ('amualaikum', 2.0),
#              ('anak', 8.0),
#              ('and', 30.0),
#              ('anda', 2.0),
#              ('angin', 5.0),
#              ('antara', 1.0),
#              ('any', 1.0),
#              ('anyway', 5.0),
#              ('apa', 41.0),
#              ('apepn', 1.0),
#              ('apepon', 1.0),
#              ('apepun', 5.0),
#              ('aplikasi', 1.0),
#              ('are', 2.0),
#              ('arive', 1.0),
#              ('arived', 5.0),
#              ('arkan', 1.0),
#              ('around', 1.0),
#              ('art', 2.0),
#              ('as', 5.0),
#              ('asal', 5.0),
#              ('asam', 4.0),
#              ('asap', 1.0),
#              ('at', 3.0),
#              ('atas', 6.0),
#              ('atau', 4.0),
#              ('au', 1.0),
#              ('aum', 1.0),
#              ('awak', 1.0),
#              ('awal', 1.0),
#              ('awesome', 1.0),
#              ('azhar', 4.0),
#              ('azharfood', 1.0),
#              ('azu', 1.0),
#              ('baca', 1.0),
#              ('bad', 7.0),
#              ('bagai', 1.0),
#              ('bagi', 41.0),
#              ('bagitahu', 1.0),
#              ('bagus', 44.0),
#              ('baha', 1.0),
#              ('bahagian', 2.0),
#              ('bahalu', 1.0),
#              ('bahasa', 1.0),
#              ('bahulu', 15.0),
#              ('baik', 282.0),
#              ('baiki', 1.0),
#              ('bajet', 1.0),
#              ('baju', 2.0),
#              ('balang', 11.0),
#              ('balas', 1.0),
#              ('balerbaloi', 1.0),
#              ('balik', 6.0),
#              ('baling', 4.0),
#              ('baloi', 1.0),
#              ('balut', 7.0),
#              ('balutan', 3.0),
#              ('bangkit', 3.0),
#              ('bantat', 1.0),
#              ('banyak', 53.0),
#              ('banyakan', 1.0),
#              ('banyka', 1.0),
#              ('barang', 151.0),
#              ('baru', 19.0),
#              ('basah', 5.0),
#              ('based', 1.0),
#              ('batang', 10.0),
#              ('batik', 1.0),
#              ('batu', 1.0),
#              ('bau', 3.0),
#              ('baulu', 2.0),
#              ('bawah', 3.0),
#              ('bawang', 8.0),
#              ('bayar', 1.0),
#              ('be', 2.0),
#              ('bean', 1.0),
#              ('because', 1.0),
#              ('before', 1.0),
#              ('beg', 1.0),
#              ('begini', 1.0),
#              ('begitu', 4.0),
#              ('bekang', 1.0),
#              ('bekas', 20.0),
#              ('beli', 112.0),
#              ('belikan', 3.0),
#              ('belimbing', 1.0),
#              ('belum', 27.0),
#              ('benda', 1.0),
#              ('bentuk', 1.0),
#              ('beranak', 1.0),
#              ('berapa', 13.0),
#              ('berat', 1.0),
#              ('berbaloi', 18.0),
#              ('berbanding', 2.0),
#              ('berbuas', 1.0),
#              ('berbuka', 4.0),
#              ('berderai', 1.0),
#              ('berempah', 1.0),
#              ('bergaya', 1.0),
#              ('bergerak', 1.0),
#              ('bergoncang', 1.0),
#              ('berhari', 2.0),
#              ('berhati', 1.0),
#              ('berhenti', 6.0),
#              ('beri', 1.0),
#              ('beritahu', 1.0),
#              ('berkali', 3.0),
#              ('berkenaan', 3.0),
#              ('berketul', 1.0),
#              ('berkualati', 1.0),
#              ('berkualiti', 1.0),
#              ('berkulat', 1.0),
#              ('berkuliti', 1.0),
#              ('berlapis', 1.0),
#              ('berlubang', 1.0),
#              ('bermanfaat', 1.0),
#              ('berminat', 1.0),
#              ('berminggu', 1.0),
#              ('berminyak', 5.0),
#              ('berpadanan', 1.0),
#              ('berpatutan', 3.0),
#              ('berpe', 1.0),
#              ('berpuas', 6.0),
#              ('berpuasa', 2.0),
#              ('bersama', 2.0),
#              ('bersih', 1.0),
#              ('bertanggungjwb', 2.0),
#              ('bertekstur', 1.0),
#              ('berterabur', 1.0),
#              ('berurusan', 2.0),
#              ('beryl', 1.0),
#              ('besar', 8.0),
#              ('best', 9.0),
#              ('bethol', 1.0),
#              ('better', 3.0),
#              ('betul', 12.0),
#              ('bggian', 1.0),
#              ('bgkusan', 2.0),
#              ('bgth', 1.0),
#              ('bhgn', 1.0),
#              ('biar', 1.0),
#              ('biasa', 45.0),
#              ('biaskut', 1.0),
#              ('big', 1.0),
#              ('bila', 15.0),
#              ('bilis', 9.0),
#              ('bincang', 3.0),
#              ('bintang', 16.0),
#              ('birokrasi', 1.0),
#              ('birthday', 2.0),
#              ('biskut', 16.0),
#              ('bismillah', 1.0),
#              ('bisnis', 1.0),
#              ('bit', 7.0),
#              ('blis', 1.0),
#              ('blouse', 1.0),
#              ('bls', 1.0),
#              ('bly', 1.0),
#              ('bngkit', 1.0),
#              ('bngkusan', 2.0),
#              ('bocor', 4.0),
#              ('boh', 2.0),
#              ('bola', 2.0),
#              ('boleh', 103.0),
#              ('bolh', 1.0),
#              ('bolih', 1.0),
#              ('borong', 2.0),
#              ('bos', 1.0),
#              ('bot', 1.0),
#              ('botol', 12.0),
#              ('box', 3.0),
#              ('bpuasa', 1.0),
#              ('brand', 2.0),
#              ('broke', 1.0),
#              ('bronice', 1.0),
#              ('brooch', 1.0),
#              ('brownies', 1.0),
#              ('bsnes', 1.0),
#              ('btng', 1.0),
#              ('buah', 15.0),
#              ('buahan', 1.0),
#              ('buang', 1.0),
#              ('buat', 16.0),
#              ('bub', 44.0),
#              ('bubles', 1.0),
#              ('bublewrap', 4.0),
#              ('bubuh', 1.0),
#              ('bucu', 1.0),
#              ('budi', 1.0),
#              ('buka', 7.0),
#              ('bukan', 18.0),
#              ('bulan', 6.0),
#              ('bun', 1.0),
#              ('buncit', 1.0),
#              ('bund', 2.0),
#              ('bunga', 1.0),
#              ('bungkuih', 1.0),
#              ('bungkus', 14.0),
#              ('bungkusan', 28.0),
#              ('burb', 1.0),
#              ('buruk', 10.0),
#              ('busines', 1.0),
#              ('but', 22.0),
#              ('buter', 4.0),
#              ('buterscotch', 2.0),
#              ('buy', 3.0),
#              ('buyer', 2.0),
#              ('bwg', 2.0),
#              ('by', 10.0),
#              ('cadangkan', 1.0),
#              ('cair', 4.0),
#              ('cakap', 7.0),
#              ('cake', 3.0),
#              ('campak', 3.0),
#              ('can', 3.0),
#              ('cantek', 1.0),
#              ('cantik', 4.0),
#              ('cara', 4.0),
#              ('card', 2.0),
#              ('cari', 2.0),
#              ('carot', 1.0),
#              ('cawan', 1.0),
#              ('cedok', 1.0),
#              ('cek', 2.0),
#              ('celebrate', 1.0),
#              ('cemane', 1.0),
#              ('cepat', 83.0),
#              ('cerita', 2.0),
#              ('cermai', 3.0),
#              ('cermat', 3.0),
#              ('certain', 2.0),
#              ('chat', 3.0),
#              ('che', 3.0),
#              ('check', 3.0),
#              ('cheese', 6.0),
#              ('chenor', 1.0),
#              ('chiang', 2.0),
#              ('chiangrai', 2.0),
#              ('chinese', 1.0),
#              ('chips', 2.0),
#              ('choc', 1.0),
#              ('choco', 1.0),
#              ('chocojar', 3.0),
#              ('chocojarleleh', 1.0),
#              ('choice', 1.0),
#              ('chrunchy', 1.0),
#              ('churn', 1.0),
#              ('cibai', 1.0),
#              ('cili', 2.0),
#              ('cincang', 2.0),
#              ('cincin', 1.0),
#              ('citarasa', 6.0),
#              ('citerasa', 1.0),
#              ('ckit', 3.0),
#              ('class', 2.0),
#              ('cmpk', 1.0),
#              ('cococrunch', 1.0),
#              ('cod', 1.0),
#              ('coin', 1.0),
#              ('coklat', 12.0),
#              ('cokletjar', 1.0),
#              ('colet', 1.0),
#              ('collect', 2.0),
#              ('collector', 2.0),
#              ('comel', 2.0),
#              ('compare', 1.0),
#              ('condition', 2.0),
#              ('confirm', 2.0),
#              ('container', 2.0),
#              ('cookies', 1.0),
#              ('could', 1.0),
#              ('courier', 7.0),
#              ('crack', 1.0),
#              ('cracked', 1.0),
#              ('craving', 3.0),
#              ('crispy', 1.0),
#              ('crpat', 1.0),
#              ('crunch', 1.0),
#              ('crunchy', 6.0),
#              ('ct', 1.0),
#              ('cuba', 11.0),
#              ('cuci', 1.0),
#              ('cukup', 17.0),
#              ('cuma', 68.0),
#              ('cun', 1.0),
#              ('cup', 2.0),
#              ('curier', 1.0),
#              ('customer', 6.0),
#              ('cuting', 1.0),
#              ('daging', 2.0),
#              ('dagingrepeat', 1.0),
#              ('dah', 184.0),
#              ('dail', 1.0),
#              ('dak', 5.0),
#              ('dalam', 106.0),
#              ('damage', 1.0),
#              ('damaged', 1.0),
#              ('dan', 138.0),
#              ('dapat', 44.0),
#              ('dari', 43.0),
#              ('daripada', 4.0),
#              ('datang', 10.0),
#              ('day', 1.0),
#              ('days', 2.0),
#              ('dbndingkan', 1.0),
#              ('dealer', 1.0),
#              ('dec', 1.0),
#              ('definitely', 2.0),
#              ('dekat', 25.0),
#              ('delay', 1.0),
#              ('delicious', 1.0),
#              ('delivary', 1.0),
#              ('deliver', 2.0),
#              ('delivery', 39.0),
#              ('dendeng', 2.0),
#              ('dengan', 132.0),
#              ('dengn', 1.0),
#              ('dengna', 1.0),
#              ('depan', 1.0),
#              ('deram', 8.0),
#              ('derita', 1.0),
#              ('dha', 1.0),
#              ('di', 32.0),
#              ('dia', 59.0),
#              ('diaktifkan', 1.0),
#              ('diakui', 2.0),
#              ('dibaiki', 1.0),
#              ('dibalut', 6.0),
#              ('dibawa', 2.0),
#              ('dibayangkan', 1.0),
#              ('dibeli', 1.0),
#              ('diberikan', 2.0),
#              ('dibuat', 1.0),
#              ('dibungkus', 7.0),
#              ('dicadangkan', 1.0),
#              ('did', 1.0),
#              ('didalam', 4.0),
#              ('didlm', 1.0),
#              ('didn', 1.0),
#              ('dif', 1.0),
#              ('difahami', 1.0),
#              ('digalakan', 1.0),
#              ('dihantar', 2.0),
#              ('dihidangkan', 1.0),
#              ('dikatakan', 1.0),
#              ('diletak', 1.0),
#              ('diluar', 2.0),
#              ('dimakan', 6.0),
#              ('dimasukan', 2.0),
#              ('dimulut', 1.0),
#              ('dimurahkan', 2.0),
#              ('dipek', 3.0),
#              ('diperbaiki', 3.0),
#              ('dipesan', 1.0),
#              ('direview', 1.0),
#              ('diri', 2.0),
#              ('disapointed', 3.0),
#              ('disapoints', 1.0),
#              ('disarankan', 1.0),
#              ('disebabkan', 3.0),
#              ('diselitkan', 1.0),
#              ('disi', 1.0),
#              ('disiplin', 1.0),
#              ('diterima', 30.0),
#              ('ditmbh', 1.0),
#              ('dng', 3.0),
#              ('doakan', 1.0),
#              ('dok', 2.0),
#              ('doorgift', 1.0),
#              ('dos', 1.0),
#              ('doub', 1.0),
#              ('dry', 1.0),
#              ('dterima', 2.0),
#              ('dtrima', 1.0),
#              ('dua', 10.0),
#              ('duber', 1.0),
#              ('due', 2.0),
#              ('duit', 5.0),
#              ('dulu', 14.0),
#              ('dunia', 1.0),
#              ('ea', 1.0),
#              ('eatab', 1.0),
#              ('edit', 1.0),
#              ('efficient', 2.0),
#              ('effort', 1.0),
#              ('eggyolk', 2.0),
#              ('ekspres', 1.0),
#              ('elakan', 1.0),
#              ('elemen', 1.0),
#              ('elok', 39.0),
#              ('empat', 2.0),
#              ('emping', 1.0),
#              ('enak', 1.0),
#              ('enough', 1.0),
#              ('ensem', 1.0),
#              ('entah', 3.0),
#              ('erm', 1.0),
#              ('es', 2.0),
#              ('esok', 3.0),
#              ('even', 2.0),
#              ('eventho', 1.0),
#              ('everything', 1.0),
#              ('excellent', 2.0),
#              ('exp', 2.0),
#              ('expect', 1.0),
#              ('expectation', 4.0),
#              ('expected', 1.0),
#              ('expired', 4.0),
#              ('expreas', 1.0),
#              ('extra', 2.0),
#              ('faktor', 1.0),
#              ('family', 3.0),
#              ('far', 5.0),
#              ('fast', 26.0),
#              ('fastshiping', 1.0),
#              ('favorite', 1.0),
#              ('fine', 2.0),
#              ('first', 5.0),
#              ('fisikal', 1.0),
#              ('flavour', 1.0),
#              ('florentine', 1.0),
#              ('foam', 1.0),
#              ('follow', 1.0),
#              ('following', 1.0),
#              ('food', 4.0),
#              ('for', 19.0),
#              ('founder', 1.0),
#              ('fra', 9.0),
#              ('free', 12.0),
#              ('fresh', 2.0),
#              ('friendly', 2.0),
#              ('from', 2.0),
#              ('fruits', 1.0),
#              ('future', 1.0),
#              ('gamak', 2.0),
#              ('gambar', 8.0),
#              ('gambr', 1.0),
#              ('ganas', 1.0),
#              ('ganti', 2.0),
#              ('gantikan', 2.0),
#              ('gara', 1.0),
#              ('garing', 4.0),
#              ('gateway', 1.0),
#              ('gebu', 3.0),
#              ('gedabak', 1.0),
#              ('gemuk', 5.0),
#              ('gemuks', 1.0),
#              ('gerobok', 1.0),
#              ('gesek', 1.0),
#              ('get', 2.0),
#              ('gift', 5.0),
#              ('gigi', 3.0),
#              ('gigih', 1.0),
#              ('gigit', 1.0),
#              ('gila', 22.0),
#              ('giller', 1.0),
#              ('gituw', 1.0),
#              ('give', 2.0),
#              ('gladly', 1.0),
#              ('gm', 1.0),
#              ('gmbo', 1.0),
#              ('god', 1.0),
#              ('gold', 1.0),
#              ('gona', 1.0),
#              ('good', 137.0),
#              ('goodjob', 1.0),
#              ('goods', 1.0),
#              ('goreng', 1.0),
#              ('got', 3.0),
#              ('gud', 1.0),
#              ('gula', 5.0),
#              ('gulung', 3.0),
#              ('guna', 10.0),
#              ('gunakan', 1.0),
#              ('ha', 2.0),
#              ('habis', 17.0),
#              ('habuk', 2.0),
#              ('had', 1.0),
#              ('hadiah', 2.0),
#              ('haha', 17.0),
#              ('haih', 1.0),
#              ('hal', 1.0),
#              ('halal', 1.0),
#              ('halalkan', 2.0),
#              ('halia', 1.0),
#              ('halus', 1.0),
#              ('hampas', 1.0),
#              ('hampir', 4.0),
#              ('hancur', 91.0),
#              ('hancus', 1.0),
#              ('hand', 1.0),
#              ('handling', 1.0),
#              ('hangit', 4.0),
#              ('hangpa', 2.0),
#              ('hangus', 1.0),
#              ('hani', 1.0),
#              ('hantar', 9.0),
#              ('hantaran', 1.0),
#              ('hanyir', 2.0),
#              ('hapak', 1.0),
#              ('happy', 2.0),
#              ('harap', 32.0),
#              ('harda', 1.0),
#              ('harga', 36.0),
#              ('hari', 53.0),
#              ('harm', 1.0),
#              ('hati', 41.0),
#              ('have', 1.0),
#              ('hb', 2.0),
#              ('heavy', 1.0),
#              ('hehe', 5.0),
#              ('high', 4.0),
#              ('hihi', 2.0),
#              ('hijau', 2.0),
#              ('hilang', 2.0),
#              ('hitam', 12.0),
#              ('hm', 1.0),
#              ('hncur', 3.0),
#              ('hndakne', 1.0),
#              ('home', 1.0),
#              ('honest', 1.0),
#              ('hope', 3.0),
#              ('hopefully', 3.0),
#              ('hotlink', 1.0),
#              ('however', 1.0),
#              ('hrpw', 1.0),
#              ('hrs', 1.0),
#              ('hti', 2.0),
#              ('htr', 1.0),
#              ('hu', 1.0),
#              ('hub', 2.0),
#              ('huhu', 4.0),
#              ('hujan', 2.0),
#              ('hujung', 1.0),
#              ('hurm', 1.0),
#              ('ibu', 1.0),
#              ('ikan', 9.0),
#              ('iklan', 2.0),
#              ('ikut', 1.0),
#              ('ilmu', 1.0),
#              ('impresed', 1.0),
#              ('improve', 11.0),
#              ('improved', 1.0),
#              ('improving', 1.0),
#              ('improvise', 1.0),
#              ('in', 10.0),
#              ('indah', 1.0),
#              ('iner', 1.0),
#              ('ingat', 4.0),
#              ('ingatkan', 2.0),
#              ('ini', 15.0),
#              ('insha', 1.0),
#              ('inshaaallah', 2.0),
#              ('inside', 2.0),
#              ('instant', 1.0),
#              ('insya', 2.0),
#              ('insyaallah', 4.0),
#              ('insyallah', 1.0),
#              ('internet', 2.0),
#              ('inti', 27.0),
#              ('into', 1.0),
#              ('is', 11.0),
#              ('isi', 6.0),
#              ('isik', 1.0),
#              ('isnin', 1.0),
#              ('isteri', 2.0),
#              ('it', 11.0),
#              ('item', 18.0),
#              ('items', 4.0),
#              ('itesm', 1.0),
#              ('its', 1.0),
#              ('itself', 1.0),
#              ('itu', 66.0),
#              ('jadi', 13.0),
#              ('jaga', 2.0),
#              ('jagung', 2.0),
#              ('jahanam', 1.0),
#              ('jamu', 1.0),
#              ('jangan', 8.0),
#              ('janji', 1.0),
#              ('jar', 2.0),
#              ('jatuh', 1.0),
#              ('jauh', 7.0),
#              ('jawa', 1.0),
#              ('jaya', 4.0),
#              ('jdikan', 1.0),
#              ('jeedjard', 1.0),
#              ('jejari', 1.0),
#              ('jem', 3.0),
#              ('jemput', 2.0),
#              ('jenama', 1.0),
#              ('jenis', 1.0),
#              ('jet', 1.0),
#              ('jika', 2.0),
#              ('jiran', 1.0),
#              ('jnjy', 1.0),
#              ('jnt', 7.0),
#              ('job', 7.0),
#              ('jual', 5.0),
#              ('juga', 52.0),
#              ('jugk', 1.0),
#              ('jujur', 4.0),
#              ('jumaat', 2.0),
#              ('jumpa', 2.0),
#              ('just', 9.0),
#              ('kacak', 1.0),
#              ('kacang', 3.0),
#              ('kadbod', 2.0),
#              ('kaitan', 3.0),
#              ('kakak', 3.0),
#              ('kalau', 46.0),
#              ('kalender', 1.0),
#              ('kali', 61.0),
#              ('kami', 1.0),
#              ('kampung', 6.0),
#              ('kan', 16.0),
#              ('kapit', 2.0),
#              ('kari', 1.0),
#              ('karipap', 14.0),
#              ('kasar', 4.0),
#              ('kaseh', 1.0),
#              ('kasih', 67.0),
#              ('kasug', 1.0),
#              ('kat', 23.0),
#              ('kata', 5.0),
#              ('kawal', 1.0),
#              ('kawan', 2.0),
#              ('kawasan', 1.0),
#              ('kaya', 1.0),
#              ('kcg', 1.0),
#              ('ke', 29.0),
#              ('keadaaan', 1.0),
#              ('keadaan', 56.0),
#              ('kebaikan', 1.0),
#              ('kebetulan', 2.0),
#              ('kecewa', 5.0),
#              ('kecil', 16.0),
#              ('kecuaian', 1.0),
#              ('kecuali', 1.0),
#              ('kedah', 1.0),
#              ('kedai', 5.0),
#              ('kedekut', 2.0),
#              ('kedua', 14.0),
#              ('keep', 3.0),
#              ('keesokan', 1.0),
#              ('kegemaran', 2.0),
#              ('kegemaranku', 1.0),
#              ('kejap', 12.0),
#              ('kek', 63.0),
#              ('kekalkan', 2.0),
#              ('kelantan', 2.0),
#              ('kelapa', 1.0),
#              ('kelihatan', 1.0),
#              ('kelonggaran', 1.0),
#              ('keluar', 7.0),
#              ('keluarga', 1.0),
#              ('kemas', 42.0),
#              ('kemasan', 2.0),
#              ('kembung', 1.0),
#              ('kemek', 11.0),
#              ('kemik', 3.0),
#              ('kemudian', 2.0),
#              ('kena', 48.0),
#              ('kencing', 1.0),
#              ('kentang', 3.0),
#              ('kepek', 1.0),
#              ('keping', 1.0),
#              ('kerana', 8.0),
#              ('kerangupan', 1.0),
#              ('keras', 26.0),
#              ('kerenah', 1.0),
#              ('kerepek', 48.0),
#              ('kerepk', 5.0),
#              ('kerepok', 1.0),
#              ('kering', 9.0),
#              ('kerja', 2.0),
#              ('keropok', 6.0),
#              ('kerosakan', 2.0),
#              ('kerusi', 1.0),
#              ('kesan', 1.0),
#              ('kesehatan', 1.0),
#              ('kesesuaian', 1.0),
#              ('kesilapan', 1.0),
#              ('kesukaan', 1.0),
#              ('ketat', 2.0),
#              ('ketiga', 1.0),
#              ('ketika', 1.0),
#              ('khamis', 1.0),
#              ('kinderbueno', 1.0),
#              ('kira', 6.0),
#              ('kisah', 2.0),
#              ('kismis', 1.0),
#              ('kita', 8.0),
#              ('kiuh', 1.0),
#              ('klik', 1.0),
#              ('komen', 4.0),
#              ('komponen', 2.0),
#              ('kondisi', 1.0),
#              ('kopi', 1.0),
#              ('kopok', 1.0),
#              ('korea', 1.0),
#              ('kot', 11.0),
#              ('kotak', 37.0),
#              ('koyak', 2.0),
#              ('krap', 1.0),
#              ('kritikal', 1.0),
#              ('kriuk', 2.0),
#              ('kropok', 1.0),
#              ('kruk', 2.0),
#              ('krup', 1.0),
#              ('kuala', 1.0),
#              ('kualiti', 11.0),
#              ('kuantiti', 2.0),
#              ('kuarantin', 1.0),
#              ('kuat', 4.0),
#              ('kuda', 1.0),
#              ('kudap', 5.0),
#              ('kudapan', 6.0),
#              ('kueh', 2.0),
#              ('kuih', 73.0),
#              ('kukus', 2.0),
#              ('kulat', 3.0),
#              ('kulit', 6.0),
#              ('kuning', 1.0),
#              ('kunyah', 9.0),
#              ('kuota', 1.0),
#              ('kurang', 44.0),
#              ('kurangkan', 4.0),
#              ('kurg', 1.0),
#              ('kurier', 3.0),
#              ('kurung', 1.0),
#              ('kut', 2.0),
#              ('la', 220.0),
#              ('lada', 1.0),
#              ('ladang', 1.0),
#              ('lag', 1.0),
#              ('lagi', 133.0),
#              ('lain', 48.0),
#              ('laju', 23.0),
#              ('lama', 21.0),
#              ('lambat', 41.0),
#              ('langsung', 2.0),
#              ('lapis', 10.0),
#              ('lapisan', 1.0),
#              ('lari', 1.0),
#              ('last', 1.0),
#              ('late', 1.0),
#              ('law', 1.0),
#              ('layak', 1.0),
#              ('layan', 11.0),
#              ('layanan', 2.0),
#              ('layer', 5.0),
#              ('lazada', 1.0),
#              ('lbh', 2.0),
#              ('least', 1.0),
#              ('lebih', 19.0),
#              ('lebihkan', 1.0),
#              ('lekat', 2.0),
#              ('leleh', 1.0),
#              ('lemak', 4.0),
#              ('lemau', 12.0),
#              ('lembab', 1.0),
#              ('lembap', 1.0),
#              ('lembik', 1.0),
#              ('lembut', 21.0),
#              ('lencun', 1.0),
#              ('lengkap', 3.0),
#              ('lepas', 18.0),
#              ('letak', 10.0),
#              ('lewat', 5.0),
#              ('ley', 2.0),
#              ('liat', 3.0),
#              ('licin', 1.0),
#              ('lid', 1.0),
#              ('lihat', 1.0),
#              ('like', 1.0),
#              ('lima', 1.0),
#              ('limau', 1.0),
#              ('list', 1.0),
#              ('lit', 2.0),
#              ('liur', 2.0),
#              ('live', 1.0),
#              ('lmbut', 1.0),
#              ('loceng', 1.0),
#              ('lockdown', 1.0),
#              ('logically', 1.0),
#              ('long', 1.0),
#              ('look', 1.0),
#              ('loose', 1.0),
#              ('lori', 1.0),
#              ('lot', 1.0),
#              ('love', 1.0),
#              ('lpis', 1.0),
#              ('lps', 2.0),
#              ('ltk', 1.0),
#              ('luar', 7.0),
#              ('lubang', 1.0),
#              ('luih', 1.0),
#              ('lumpur', 1.0),
#              ('lunyai', 2.0),
#              ('lupa', 1.0),
#              ('lusa', 1.0),
#              ('maaf', 7.0),
#              ('mac', 2.0),
#              ('macam', 57.0),
#              ('machang', 1.0),
#              ('made', 1.0),
#              ('mahal', 5.0),
#              ('mahupun', 1.0),
#              ('main', 4.0),
#              ('maintain', 1.0),
#              ('maju', 5.0),
#              ('mak', 9.0),
#              ('maka', 1.0),
#              ('makan', 70.0),
#              ('makanan', 7.0),
#              ('maklum', 2.0),
#              ('malam', 3.0),
#              ('malan', 1.0),
#              ('malas', 2.0),
#              ('malaysia', 11.0),
#              ('malinjo', 1.0),
#              ('malu', 1.0),
#              ('mampus', 1.0),
#              ('man', 1.0),
#              ('mana', 8.0),
#              ('manfaatkan', 1.0),
#              ('manis', 70.0),
#              ('mantap', 3.0),
#              ('mantop', 1.0),
#              ('mantul', 1.0),
#              ('march', 1.0),
#              ('marvellous', 3.0),
#              ('masa', 27.0),
#              ('masage', 1.0),
#              ('masak', 2.0),
#              ('masakan', 1.0),
#              ('masalah', 5.0),
#              ('masam', 10.0),
#              ('masih', 14.0),
#              ('masin', 11.0),
#              ('masing', 1.0),
#              ('masuk', 8.0),
#              ('masukan', 2.0),
#              ('mat', 1.0),
#              ('mata', 1.0),
#              ('mayb', 1.0),
#              ('maybe', 11.0),
#              ('mbps', 1.0),
#              ('mc', 1.0),
#              ('mcm', 1.0),
#              ('mco', 1.0),
#              ('me', 6.0),
#              ('meggi', 1.0),
#              ('meh', 1.0),
#              ('mei', 1.0),
#              ('melaka', 1.0),
#              ('melayu', 1.0),
#              ('melebihi', 1.0),
#              ('melekat', 2.0),
#              ('melekit', 2.0),
#              ('meleleh', 2.0),
#              ('melt', 1.0),
#              ('meluah', 1.0),
#              ('memang', 77.0),
#              ('membaling', 1.0),
#              ('membantu', 1.0),
#              ('membeli', 1.0),
#              ('memberi', 1.0),
#              ('memenuhi', 3.0),
#              ('memuaskan', 13.0),
#              ('memudahkan', 1.0),
#              ('mencari', 1.0),
#              ('mencuba', 1.0),
#              ('mencukupi', 2.0),
#              ('menepati', 2.0),
#              ('meneram', 1.0),
#              ('mengadap', 1.0),
#              ('mengambil', 2.0),
#              ('mengecewakan', 4.0),
#              ('mengena', 2.0),
#              ('menghampakan', 1.0),
#              ('mengidam', 6.0),
#              ('mengikut', 1.0),
#              ('mengun', 3.0),
#              ('menjadi', 1.0),
#              ('menjaga', 1.0),
#              ('menjawab', 1.0),
#              ('menjual', 2.0),
#              ('mention', 3.0),
#              ('menukar', 1.0),
#              ('menunggu', 1.0),
#              ('menyambut', 1.0),
#              ('menyebabkan', 1.0),
#              ('menyedapkan', 1.0),
#              ('menyelerakan', 2.0),
#              ('menyesal', 2.0),
#              ('merah', 1.0),
#              ('merasa', 1.0),
#              ('mertua', 1.0),
#              ('meruap', 1.0),
#              ('mesej', 1.0),
#              ('mesra', 1.0),
#              ('mesti', 5.0),
#              ('mgo', 1.0),
#              ('mh', 1.0),
#              ('minggu', 7.0),
#              ('mini', 2.0),
#              ('minta', 5.0),
#              ('minuman', 1.0),
#              ('minyak', 10.0),
#              ('miri', 1.0),
#              ('miss', 2.0),
#              ('mjdi', 1.0),
#              ('mknan', 2.0),
#              ('mngidam', 1.0),
#              ('mnis', 4.0),
#              ('mnt', 1.0),
#              ('moga', 1.0),
#              ('moist', 9.0),
#              ('molek', 1.0),
#              ('mom', 2.0),
#              ('monday', 1.0),
#              ('money', 3.0),
#              ('mood', 1.0),
#              ('mooncake', 1.0),
#              ('more', 2.0),
#              ('mouth', 1.0),
#              ('msg', 1.0),
#              ('msh', 2.0),
#              ('msm', 1.0),
#              ('muak', 2.0),
#              ('muaskan', 1.0),
#              ('muat', 1.0),
#              ('much', 1.0),
#              ('mudah', 5.0),
#              ('mujur', 1.0),
#              ('mula', 3.0),
#              ('mulut', 3.0),
#              ('mung', 1.0),
#              ('mungkin', 22.0),
#              ('murah', 27.0),
#              ('musim', 5.0),
#              ('my', 11.0),
#              ('myb', 4.0),
#              ('naik', 3.0),
#              ('nak', 71.0),
#              ('nama', 1.0),
#              ('nampak', 10.0),
#              ('namun', 1.0),
#              ('nanti', 37.0),
#              ('nasib', 19.0),
#              ('nd', 5.0),
#              ('nenas', 10.0),
#              ('never', 1.0),
#              ('news', 1.0),
#              ('next', 11.0),
#              ('ngam', 2.0),
#              ('ngap', 5.0),
#              ('ngidam', 1.0),
#              ('ni', 125.0),
#              ('niaga', 1.0),
#              ('niat', 1.0),
#              ...])

# %%
count_pos = len(count_wdict_pos)
count_pos
# Out:
# 1715

# %%
#create count(w, neg)
from collections import OrderedDict

count_wdict_neg = OrderedDict(sorted(docs_cw[1].items())) # index 1 is negative sentiment

# %%
count_wdict_neg
# Out:
# OrderedDict([('about', 1.0),
#              ('acaner', 1.0),
#              ('accept', 1.0),
#              ('act', 1.0),
#              ('ada', 147.0),
#              ('adalah', 2.0),
#              ('adik', 2.0),
#              ('adil', 1.0),
#              ('adjust', 1.0),
#              ('aduan', 1.0),
#              ('aduh', 4.0),
#              ('adunan', 1.0),
#              ('advice', 1.0),
#              ('after', 3.0),
#              ('agak', 31.0),
#              ('ah', 1.0),
#              ('ahad', 1.0),
#              ('air', 4.0),
#              ('ais', 3.0),
#              ('ajar', 3.0),
#              ('akan', 10.0),
#              ('akg', 1.0),
#              ('akhir', 2.0),
#              ('akhirat', 1.0),
#              ('aku', 7.0),
#              ('alahai', 2.0),
#              ('alam', 5.0),
#              ('alamat', 1.0),
#              ('alami', 1.0),
#              ('alang', 1.0),
#              ('alasan', 5.0),
#              ('alert', 4.0),
#              ('alhamdulillah', 7.0),
#              ('all', 6.0),
#              ('allah', 4.0),
#              ('almond', 1.0),
#              ('almost', 1.0),
#              ('alot', 1.0),
#              ('alsan', 1.0),
#              ('also', 1.0),
#              ('altast', 1.0),
#              ('am', 1.0),
#              ('aman', 1.0),
#              ('amanah', 1.0),
#              ('amat', 3.0),
#              ('ambil', 23.0),
#              ('amboi', 1.0),
#              ('aming', 4.0),
#              ('amk', 2.0),
#              ('amualaikum', 1.0),
#              ('anak', 9.0),
#              ('and', 26.0),
#              ('anda', 3.0),
#              ('angin', 27.0),
#              ('angsana', 1.0),
#              ('another', 2.0),
#              ('antar', 1.0),
#              ('antara', 1.0),
#              ('any', 1.0),
#              ('anyhow', 1.0),
#              ('anyway', 3.0),
#              ('apa', 56.0),
#              ('apabila', 1.0),
#              ('apepun', 1.0),
#              ('api', 2.0),
#              ('apr', 2.0),
#              ('aprove', 2.0),
#              ('are', 1.0),
#              ('area', 2.0),
#              ('arive', 2.0),
#              ('arived', 1.0),
#              ('as', 1.0),
#              ('asal', 5.0),
#              ('asap', 2.0),
#              ('ast', 1.0),
#              ('at', 6.0),
#              ('atas', 4.0),
#              ('atau', 10.0),
#              ('atention', 1.0),
#              ('awak', 7.0),
#              ('awal', 2.0),
#              ('ayam', 2.0),
#              ('ayo', 1.0),
#              ('azhar', 1.0),
#              ('bab', 1.0),
#              ('baby', 1.0),
#              ('baca', 8.0),
#              ('bad', 18.0),
#              ('bag', 1.0),
#              ('bagai', 1.0),
#              ('bagaiman', 1.0),
#              ('bagaimana', 1.0),
#              ('bagel', 20.0),
#              ('bagi', 47.0),
#              ('bagitahu', 1.0),
#              ('bagus', 18.0),
#              ('bahagian', 2.0),
#              ('bahagie', 1.0),
#              ('bahalu', 1.0),
#              ('bahan', 3.0),
#              ('bahaya', 1.0),
#              ('bahulu', 30.0),
#              ('baik', 49.0),
#              ('baiki', 8.0),
#              ('bakery', 2.0),
#              ('bal', 1.0),
#              ('balang', 5.0),
#              ('balangpun', 1.0),
#              ('balas', 2.0),
#              ('balasan', 2.0),
#              ('balik', 6.0),
#              ('baling', 2.0),
#              ('balut', 6.0),
#              ('balutan', 1.0),
#              ('balutanya', 2.0),
#              ('bancuh', 1.0),
#              ('banding', 1.0),
#              ('bandung', 2.0),
#              ('bangel', 1.0),
#              ('bangkit', 1.0),
#              ('bantat', 1.0),
#              ('banting', 2.0),
#              ('banyak', 54.0),
#              ('banyk', 1.0),
#              ('barang', 105.0),
#              ('barangan', 1.0),
#              ('baru', 43.0),
#              ('basah', 14.0),
#              ('based', 1.0),
#              ('basi', 14.0),
#              ('batang', 16.0),
#              ('batch', 2.0),
#              ('bau', 27.0),
#              ('baulu', 1.0),
#              ('bawa', 2.0),
#              ('bawah', 4.0),
#              ('bayangkan', 1.0),
#              ('bayar', 7.0),
#              ('bazir', 1.0),
#              ('be', 4.0),
#              ('beberapa', 3.0),
#              ('because', 7.0),
#              ('beda', 1.0),
#              ('before', 4.0),
#              ('beg', 4.0),
#              ('begitu', 3.0),
#              ('bekas', 29.0),
#              ('bekerja', 1.0),
#              ('beku', 2.0),
#              ('belakang', 1.0),
#              ('beli', 139.0),
#              ('belian', 1.0),
#              ('belimbing', 2.0),
#              ('belum', 5.0),
#              ('benar', 1.0),
#              ('benda', 7.0),
#              ('bentuk', 5.0),
#              ('benua', 1.0),
#              ('berabuk', 1.0),
#              ('berair', 1.0),
#              ('berangin', 1.0),
#              ('berapa', 20.0),
#              ('berape', 1.0),
#              ('berat', 3.0),
#              ('beratur', 1.0),
#              ('berbaloi', 13.0),
#              ('berbalut', 1.0),
#              ('berbau', 5.0),
#              ('berbeza', 1.0),
#              ('berbulu', 2.0),
#              ('bercakap', 1.0),
#              ('bercantum', 1.0),
#              ('berdasarkan', 1.0),
#              ('berderai', 3.0),
#              ('berdosa', 1.0),
#              ('beretika', 1.0),
#              ('berfaedah', 1.0),
#              ('berharap', 1.0),
#              ('berhari', 1.0),
#              ('berhati', 2.0),
#              ('beri', 2.0),
#              ('berisi', 1.0),
#              ('beritahu', 4.0),
#              ('berjaya', 1.0),
#              ('berkali', 2.0),
#              ('berkecai', 1.0),
#              ('berkualiti', 1.0),
#              ('berkulat', 41.0),
#              ('berlapis', 2.0),
#              ('berlapuk', 1.0),
#              ('berlendir', 3.0),
#              ('berminggu', 1.0),
#              ('berminyak', 9.0),
#              ('berniaga', 3.0),
#              ('berpada', 2.0),
#              ('berpatutan', 2.0),
#              ('berpendapat', 1.0),
#              ('berprasangka', 1.0),
#              ('berpuasa', 1.0),
#              ('bersalah', 1.0),
#              ('bersama', 2.0),
#              ('berselera', 1.0),
#              ('bersemut', 5.0),
#              ('bersepah', 1.0),
#              ('bersih', 1.0),
#              ('bertanggungjawab', 3.0),
#              ('bertanggungjawap', 1.0),
#              ('bertekak', 1.0),
#              ('bertepung', 1.0),
#              ('berterabur', 4.0),
#              ('bertgugjwab', 1.0),
#              ('bertindih', 1.0),
#              ('berulat', 2.0),
#              ('besar', 6.0),
#              ('best', 4.0),
#              ('bestari', 1.0),
#              ('betapa', 1.0),
#              ('better', 7.0),
#              ('betul', 25.0),
#              ('beyond', 1.0),
#              ('beza', 8.0),
#              ('bezakan', 1.0),
#              ('bhgian', 1.0),
#              ('biar', 4.0),
#              ('biarkan', 1.0),
#              ('biasa', 39.0),
#              ('biji', 3.0),
#              ('bikarbonat', 1.0),
#              ('bila', 48.0),
#              ('bilis', 7.0),
#              ('binatang', 1.0),
#              ('bintang', 5.0),
#              ('birit', 2.0),
#              ('biru', 7.0),
#              ('biscof', 1.0),
#              ('biscuit', 1.0),
#              ('biscuits', 1.0),
#              ('biskut', 12.0),
#              ('bisnes', 2.0),
#              ('bit', 1.0),
#              ('bitan', 1.0),
#              ('bkak', 1.0),
#              ('blas', 1.0),
#              ('blintgk', 1.0),
#              ('bls', 1.0),
#              ('bluebery', 1.0),
#              ('bluetick', 1.0),
#              ('bniaga', 1.0),
#              ('bnsa', 1.0),
#              ('bocor', 4.0),
#              ('bodoh', 2.0),
#              ('bolat', 1.0),
#              ('boleh', 86.0),
#              ('bolela', 1.0),
#              ('bos', 3.0),
#              ('botol', 9.0),
#              ('boub', 1.0),
#              ('bought', 2.0),
#              ('box', 7.0),
#              ('boyan', 1.0),
#              ('bpe', 1.0),
#              ('braces', 1.0),
#              ('brand', 2.0),
#              ('brit', 1.0),
#              ('broken', 1.0),
#              ('brow', 1.0),
#              ('bsah', 1.0),
#              ('bsh', 1.0),
#              ('buah', 5.0),
#              ('buahulu', 1.0),
#              ('buang', 7.0),
#              ('buat', 26.0),
#              ('bub', 33.0),
#              ('bublewrap', 1.0),
#              ('budak', 3.0),
#              ('budu', 1.0),
#              ('buka', 15.0),
#              ('bukan', 40.0),
#              ('bukti', 2.0),
#              ('bulan', 1.0),
#              ('bulat', 6.0),
#              ('bun', 1.0),
#              ('bungkur', 1.0),
#              ('bungkus', 16.0),
#              ('bungkusan', 19.0),
#              ('burok', 1.0),
#              ('buruk', 20.0),
#              ('busuk', 3.0),
#              ('but', 15.0),
#              ('buter', 2.0),
#              ('buy', 1.0),
#              ('buyer', 8.0),
#              ('by', 8.0),
#              ('bye', 1.0),
#              ('cadangkan', 1.0),
#              ('cadbury', 2.0),
#              ('cahaya', 1.0),
#              ('cair', 3.0),
#              ('cakap', 36.0),
#              ('cakapa', 1.0),
#              ('cake', 11.0),
#              ('call', 1.0),
#              ('camner', 2.0),
#              ('campak', 4.0),
#              ('campuran', 1.0),
#              ('can', 2.0),
#              ('cancel', 12.0),
#              ('cantik', 4.0),
#              ('cap', 25.0),
#              ('capai', 1.0),
#              ('capucino', 1.0),
#              ('cara', 6.0),
#              ('caramel', 1.0),
#              ('cari', 4.0),
#              ('carot', 1.0),
#              ('cau', 1.0),
#              ('cebisan', 1.0),
#              ('cek', 1.0),
#              ('cendawan', 1.0),
#              ('cente', 1.0),
#              ('cepat', 25.0),
#              ('cerita', 4.0),
#              ('cermat', 1.0),
#              ('chat', 16.0),
#              ('che', 3.0),
#              ('cheaper', 1.0),
#              ('check', 7.0),
#              ('cheese', 10.0),
#              ('chewy', 3.0),
#              ('chiang', 3.0),
#              ('chiller', 1.0),
#              ('chilli', 1.0),
#              ('china', 1.0),
#              ('chinese', 1.0),
#              ('chip', 9.0),
#              ('chips', 4.0),
#              ('choc', 3.0),
#              ('choclate', 1.0),
#              ('choco', 1.0),
#              ('chocolate', 5.0),
#              ('cili', 5.0),
#              ('ciri', 1.0),
#              ('cirit', 2.0),
#              ('cis', 1.0),
#              ('citarasa', 3.0),
#              ('ckit', 3.0),
#              ('cklat', 1.0),
#              ('ckt', 1.0),
#              ('clear', 1.0),
#              ('cloud', 1.0),
#              ('cmw', 2.0),
#              ('cnc', 1.0),
#              ('cncel', 1.0),
#              ('cny', 1.0),
#              ('coco', 1.0),
#              ('cokelat', 1.0),
#              ('coki', 1.0),
#              ('coklat', 27.0),
#              ('coklet', 1.0),
#              ('colour', 1.0),
#              ('comment', 1.0),
#              ('compare', 1.0),
#              ('compared', 1.0),
#              ('complete', 1.0),
#              ('conclusion', 1.0),
#              ('condition', 2.0),
#              ('cononet', 1.0),
#              ('contact', 1.0),
#              ('control', 2.0),
#              ('cookies', 6.0),
#              ('cop', 1.0),
#              ('courier', 13.0),
#              ('cover', 1.0),
#              ('covid', 1.0),
#              ('crack', 1.0),
#              ('cracker', 3.0),
#              ('craving', 3.0),
#              ('crispy', 3.0),
#              ('crunch', 2.0),
#              ('crunchy', 1.0),
#              ('crushed', 1.0),
#              ('cuai', 1.0),
#              ('cuba', 4.0),
#              ('cukup', 9.0),
#              ('cuma', 20.0),
#              ('cup', 1.0),
#              ('cury', 1.0),
#              ('customer', 13.0),
#              ('customers', 1.0),
#              ('cut', 1.0),
#              ('daging', 7.0),
#              ('dah', 234.0),
#              ('dahsyat', 1.0),
#              ('dahulu', 1.0),
#              ('dak', 2.0),
#              ('dal', 1.0),
#              ('dalam', 96.0),
#              ('dalem', 1.0),
#              ('damage', 1.0),
#              ('dan', 111.0),
#              ('dapat', 131.0),
#              ('dapt', 2.0),
#              ('darah', 1.0),
#              ('dari', 53.0),
#              ('daripada', 11.0),
#              ('datang', 11.0),
#              ('dateline', 1.0),
#              ('day', 1.0),
#              ('deal', 1.0),
#              ('dealer', 1.0),
#              ('dear', 1.0),
#              ('defect', 1.0),
#              ('definitely', 1.0),
#              ('dehal', 1.0),
#              ('dekat', 28.0),
#              ('delay', 4.0),
#              ('delete', 1.0),
#              ('delicious', 1.0),
#              ('deliver', 4.0),
#              ('delivered', 1.0),
#              ('delivery', 47.0),
#              ('demand', 1.0),
#              ('demi', 1.0),
#              ('dengan', 115.0),
#              ('dengn', 2.0),
#              ('depan', 1.0),
#              ('der', 1.0),
#              ('deram', 4.0),
#              ('derme', 1.0),
#              ('described', 1.0),
#              ('description', 1.0),
#              ('desert', 1.0),
#              ('despite', 1.0),
#              ('dharapkan', 1.0),
#              ('dhl', 3.0),
#              ('di', 17.0),
#              ('dia', 70.0),
#              ('diam', 2.0),
#              ('dian', 2.0),
#              ('diatas', 1.0),
#              ('dibahagian', 2.0),
#              ('dibalut', 4.0),
#              ('dibayang', 1.0),
#              ('dibeli', 1.0),
#              ('diberi', 2.0),
#              ('dibersihkan', 1.0),
#              ('dibiarkan', 1.0),
#              ('dibuang', 1.0),
#              ('dibuat', 1.0),
#              ('dibuka', 1.0),
#              ('dibungkus', 1.0),
#              ('diet', 1.0),
#              ('different', 1.0),
#              ('digalakan', 1.0),
#              ('diganti', 1.0),
#              ('digigit', 1.0),
#              ('digoreng', 3.0),
#              ('dihantar', 3.0),
#              ('diharap', 3.0),
#              ('diharapkan', 2.0),
#              ('dihidangkan', 1.0),
#              ('dihtr', 1.0),
#              ('dihubungi', 1.0),
#              ('dijanjikan', 1.0),
#              ('dijawab', 1.0),
#              ('dikedai', 1.0),
#              ('dikeringkan', 1.0),
#              ('diklan', 1.0),
#              ('diklankan', 3.0),
#              ('dikunyah', 1.0),
#              ('dimakan', 4.0),
#              ('dimasuk', 1.0),
#              ('dimasuki', 1.0),
#              ('dimeterai', 1.0),
#              ('dinyatakan', 1.0),
#              ('diorder', 1.0),
#              ('diperam', 1.0),
#              ('diperbaiki', 2.0),
#              ('diperkatakan', 1.0),
#              ('dipesan', 1.0),
#              ('dipos', 3.0),
#              ('direspon', 1.0),
#              ('direview', 2.0),
#              ('disapointed', 5.0),
#              ('disapointing', 1.0),
#              ('disaponted', 1.0),
#              ('disebabkan', 3.0),
#              ('ditambah', 1.0),
#              ('ditanya', 1.0),
#              ('ditawarakan', 1.0),
#              ('diterima', 19.0),
#              ('ditinggalkan', 1.0),
#              ('dlvry', 3.0),
#              ('dng', 1.0),
#              ('do', 2.0),
#              ('doa', 1.0),
#              ('documen', 1.0),
#              ('document', 1.0),
#              ('dodol', 1.0),
#              ('dok', 1.0),
#              ('don', 2.0),
#              ('donut', 2.0),
#              ('doorgift', 1.0),
#              ('drive', 2.0),
#              ('driver', 1.0),
#              ('drp', 1.0),
#              ('dry', 6.0),
#              ('dua', 16.0),
#              ('duduk', 1.0),
#              ('duit', 15.0),
#              ('dukacita', 1.0),
#              ('dulu', 20.0),
#              ('durian', 1.0),
#              ('edib', 1.0),
#              ('edited', 3.0),
#              ('effort', 1.0),
#              ('eg', 2.0),
#              ('elak', 1.0),
#              ('elakan', 2.0),
#              ('elok', 25.0),
#              ('em', 3.0),
#              ('enak', 2.0),
#              ('end', 1.0),
#              ('enjoy', 1.0),
#              ('entah', 5.0),
#              ('enth', 1.0),
#              ('erggh', 1.0),
#              ('ergh', 1.0),
#              ('erhm', 1.0),
#              ('erm', 3.0),
#              ('esen', 1.0),
#              ('esok', 5.0),
#              ('especially', 1.0),
#              ('etika', 1.0),
#              ('even', 3.0),
#              ('eventho', 1.0),
#              ('evergreen', 1.0),
#              ('excited', 2.0),
#              ('excuses', 1.0),
#              ('expact', 1.0),
#              ('expect', 2.0),
#              ('expectation', 7.0),
#              ('expectations', 1.0),
#              ('expected', 1.0),
#              ('experience', 1.0),
#              ('expired', 6.0),
#              ('expres', 3.0),
#              ('extended', 1.0),
#              ('extra', 9.0),
#              ('facebook', 1.0),
#              ('faham', 5.0),
#              ('fair', 1.0),
#              ('far', 1.0),
#              ('fast', 6.0),
#              ('faz', 1.0),
#              ('feedback', 3.0),
#              ('feri', 7.0),
#              ('few', 3.0),
#              ('fham', 1.0),
#              ('fikir', 1.0),
#              ('fikirkan', 3.0),
#              ('finally', 1.0),
#              ('first', 15.0),
#              ('firstly', 2.0),
#              ('flavor', 1.0),
#              ('flavour', 2.0),
#              ('food', 2.0),
#              ('for', 11.0),
#              ('forward', 1.0),
#              ('fra', 5.0),
#              ('free', 4.0),
#              ('fresh', 5.0),
#              ('freshly', 1.0),
#              ('from', 1.0),
#              ('frozen', 1.0),
#              ('frus', 1.0),
#              ('frust', 9.0),
#              ('fully', 1.0),
#              ('fungal', 1.0),
#              ('fungus', 1.0),
#              ('future', 1.0),
#              ('fyi', 1.0),
#              ('gambar', 22.0),
#              ('gambarkan', 1.0),
#              ('ganti', 6.0),
#              ('gara', 1.0),
#              ('garing', 3.0),
#              ('gatal', 1.0),
#              ('gbr', 1.0),
#              ('gebu', 6.0),
#              ('gel', 1.0),
#              ('geram', 2.0),
#              ('gift', 1.0),
#              ('gigi', 3.0),
#              ('gigit', 3.0),
#              ('gila', 22.0),
#              ('give', 1.0),
#              ('god', 1.0),
#              ('golden', 1.0),
#              ('good', 6.0),
#              ('goreng', 11.0),
#              ('gram', 2.0),
#              ('great', 2.0),
#              ('gred', 2.0),
#              ('gros', 1.0),
#              ('gua', 1.0),
#              ('guarante', 1.0),
#              ('gudang', 1.0),
#              ('guess', 1.0),
#              ('gula', 4.0),
#              ('gulung', 1.0),
#              ('guna', 34.0),
#              ('gusi', 1.0),
#              ('habak', 1.0),
#              ('habis', 22.0),
#              ('habiskan', 2.0),
#              ('habuk', 1.0),
#              ('haggit', 1.0),
#              ('haha', 7.0),
#              ('hai', 2.0),
#              ('haih', 2.0),
#              ('haish', 1.0),
#              ('haiyo', 1.0),
#              ('haji', 2.0),
#              ('hal', 2.0),
#              ('halabgate', 1.0),
#              ('halal', 2.0),
#              ('halalkan', 2.0),
#              ('halus', 2.0),
#              ('hampeh', 2.0),
#              ('hampir', 9.0),
#              ('hancur', 88.0),
#              ('hand', 2.0),
#              ('hangat', 1.0),
#              ('hangit', 5.0),
#              ('hangpa', 5.0),
#              ('hangus', 5.0),
#              ('hanta', 1.0),
#              ('hantar', 20.0),
#              ('hanya', 8.0),
#              ('hanyir', 1.0),
#              ('hapak', 15.0),
#              ('hape', 1.0),
#              ('harap', 28.0),
#              ('harga', 31.0),
#              ('hari', 49.0),
#              ('hartan', 1.0),
#              ('harus', 1.0),
#              ('hati', 23.0),
#              ('have', 1.0),
#              ('hb', 12.0),
#              ('hbiskan', 1.0),
#              ('hbs', 1.0),
#              ('he', 1.0),
#              ('herba', 1.0),
#              ('hidang', 3.0),
#              ('hidup', 2.0),
#              ('high', 1.0),
#              ('higlight', 1.0),
#              ('hijau', 2.0),
#              ('hilang', 6.0),
#              ('hingga', 1.0),
#              ('hitam', 8.0),
#              ('hm', 20.0),
#              ('hncur', 4.0),
#              ('hntar', 1.0),
#              ('homemade', 3.0),
#              ('honest', 2.0),
#              ('hope', 2.0),
#              ('hopefully', 2.0),
#              ('horn', 1.0),
#              ('how', 1.0),
#              ('hq', 3.0),
#              ('htr', 1.0),
#              ('hu', 1.0),
#              ('hubungi', 1.0),
#              ('huhu', 4.0),
#              ('hujan', 3.0),
#              ('hujung', 4.0),
#              ('hurm', 1.0),
#              ('hurung', 1.0),
#              ('husband', 1.0),
#              ('husnudzon', 1.0),
#              ('hy', 1.0),
#              ('hye', 1.0),
#              ('ia', 3.0),
#              ('ialah', 1.0),
#              ('ibu', 1.0),
#              ('ice', 3.0),
#              ('if', 2.0),
#              ('ignorant', 1.0),
#              ('ignore', 3.0),
#              ('ikan', 19.0),
#              ('ikhlas', 3.0),
#              ('iklan', 5.0),
#              ('iklankan', 1.0),
#              ('iklas', 1.0),
#              ('ikllan', 1.0),
#              ('ikut', 3.0),
#              ('improve', 14.0),
#              ('improved', 1.0),
#              ('improvekan', 2.0),
#              ('improvement', 1.0),
#              ('in', 2.0),
#              ('inci', 1.0),
#              ('indah', 2.0),
#              ('inform', 6.0),
#              ('information', 2.0),
#              ('ingat', 6.0),
#              ('ingatan', 1.0),
#              ('ingatkan', 6.0),
#              ('inggit', 1.0),
#              ('ini', 24.0),
#              ('inti', 18.0),
#              ('into', 1.0),
#              ('investigation', 1.0),
#              ('is', 7.0),
#              ('isi', 9.0),
#              ('islam', 1.0),
#              ('isnin', 3.0),
#              ('issue', 1.0),
#              ('isu', 1.0),
#              ('it', 5.0),
#              ('item', 13.0),
#              ('itik', 1.0),
#              ('itu', 147.0),
#              ('jadi', 30.0),
#              ('jaga', 8.0),
#              ('jage', 1.0),
#              ('jalan', 1.0),
#              ('jalapeno', 1.0),
#              ('jam', 2.0),
#              ('jamu', 2.0),
#              ('jamuan', 1.0),
#              ('jangan', 21.0),
#              ('jangkaan', 1.0),
#              ('jarang', 2.0),
#              ('jari', 1.0),
#              ('jatuh', 1.0),
#              ('jauh', 6.0),
#              ('jawa', 1.0),
#              ('jawab', 5.0),
#              ('jawap', 1.0),
#              ('jawapan', 1.0),
#              ('jaya', 2.0),
#              ('jb', 1.0),
#              ('jelas', 1.0),
#              ('jem', 2.0),
#              ('jenama', 5.0),
#              ('jenis', 9.0),
#              ('jeras', 1.0),
#              ('jiran', 1.0),
#              ('jnj', 1.0),
#              ('jnt', 9.0),
#              ('jual', 16.0),
#              ('juga', 21.0),
#              ('jujur', 13.0),
#              ('jum', 1.0),
#              ('jumaat', 3.0),
#              ('jumpa', 7.0),
#              ('junior', 1.0),
#              ('just', 6.0),
#              ('jwpn', 1.0),
#              ('kacang', 9.0),
#              ('kadar', 1.0),
#              ('kaedah', 1.0),
#              ('kaitan', 2.0),
#              ('kaji', 2.0),
#              ('kaki', 1.0),
#              ('kalau', 37.0),
#              ('kali', 51.0),
#              ('kami', 1.0),
#              ('kampung', 6.0),
#              ('kamu', 1.0),
#              ('kan', 35.0),
#              ('kapit', 7.0),
#              ('kari', 2.0),
#              ('karipap', 10.0),
#              ('kasih', 10.0),
#              ('kasihan', 3.0),
#              ('kasturi', 3.0),
#              ('kat', 27.0),
#              ('kata', 12.0),
#              ('kategori', 1.0),
#              ('kau', 2.0),
#              ('kaut', 1.0),
#              ('kawan', 3.0),
#              ('kawasan', 1.0),
#              ('kayu', 1.0),
#              ('kcewa', 2.0),
#              ('kcik', 1.0),
#              ('kcwa', 1.0),
#              ('kdua', 1.0),
#              ('ke', 46.0),
#              ('keadaan', 21.0),
#              ('kebanyakan', 1.0),
#              ('kebersihan', 1.0),
#              ('kebersihn', 1.0),
#              ('kecewa', 60.0),
#              ('kecil', 50.0),
#              ('kecuali', 2.0),
#              ('kedaan', 1.0),
#              ('kedai', 11.0),
#              ('kedekut', 2.0),
#              ('kedua', 9.0),
#              ('keep', 1.0),
#              ('keesokan', 1.0),
#              ('kegemaran', 2.0),
#              ('kejap', 4.0),
#              ('kejar', 1.0),
#              ('keju', 1.0),
#              ('kejung', 1.0),
#              ('kek', 178.0),
#              ('kektu', 1.0),
#              ('kelakar', 1.0),
#              ('kelantan', 4.0),
#              ('keledek', 1.0),
#              ('kelemahan', 1.0),
#              ('kelewatan', 1.0),
#              ('kelihatan', 1.0),
#              ('kelirukan', 1.0),
#              ('keluar', 5.0),
#              ('keluarga', 1.0),
#              ('keluarkan', 2.0),
#              ('kemas', 8.0),
#              ('kembalikan', 1.0),
#              ('kembang', 4.0),
#              ('kembung', 1.0),
#              ('kemek', 8.0),
#              ('kemik', 3.0),
#              ('kemudian', 2.0),
#              ('kena', 54.0),
#              ('kenapa', 22.0),
#              ('kentang', 4.0),
#              ('kenyal', 1.0),
#              ('kepada', 5.0),
#              ('kepala', 2.0),
#              ('kepam', 1.0),
#              ('kepedasan', 1.0),
#              ('kepek', 1.0),
#              ('keping', 1.0),
#              ('kerana', 5.0),
#              ('keras', 55.0),
#              ('kereana', 1.0),
#              ('kerepek', 83.0),
#              ('kereper', 1.0),
#              ('kerepk', 1.0),
#              ('kereta', 1.0),
#              ('keria', 1.0),
#              ('kering', 22.0),
#              ('keropok', 32.0),
#              ('kertas', 1.0),
#              ('kerupuk', 1.0),
#              ('kesan', 1.0),
#              ('kesedapa', 1.0),
#              ('keselamatan', 2.0),
#              ('keseluruhan', 2.0),
#              ('keseluruhanya', 1.0),
#              ('kesilapan', 3.0),
#              ('ketar', 1.0),
#              ('ketiga', 4.0),
#              ('ketika', 1.0),
#              ('ketupat', 2.0),
#              ('khabar', 2.0),
#              ('khairul', 4.0),
#              ('khamis', 1.0),
#              ('kilang', 6.0),
#              ('kinderbueno', 1.0),
#              ('kira', 2.0),
#              ('kisah', 2.0),
#              ('kisar', 1.0),
#              ('kita', 7.0),
#              ('klik', 1.0),
#              ('know', 2.0),
#              ('ko', 1.0),
#              ('koko', 2.0),
#              ('komen', 8.0),
#              ('komunikasi', 2.0),
#              ('konon', 1.0),
#              ('konsisten', 1.0),
#              ('kosong', 4.0),
#              ('kot', 6.0),
#              ('kota', 1.0),
#              ('kotak', 30.0),
#              ('kotor', 1.0),
#              ('koyak', 2.0),
#              ('koyakan', 1.0),
#              ('kras', 1.0),
#              ('krepek', 2.0),
#              ('krg', 1.0),
#              ('krim', 1.0),
#              ('kropok', 1.0),
#              ('ksong', 1.0),
#              ('kuah', 1.0),
#              ('kuala', 2.0),
#              ('kualiti', 32.0),
#              ('kuat', 11.0),
#              ('kuda', 4.0),
#              ('kuig', 1.0),
#              ('kuih', 47.0),
#              ('kukuh', 1.0),
#              ('kukus', 5.0),
#              ('kulat', 10.0),
#              ('kulim', 1.0),
#              ('kulit', 9.0),
#              ('kuning', 3.0),
#              ('kunyah', 3.0),
#              ('kurang', 51.0),
#              ('kurg', 1.0),
#              ('kurier', 4.0),
#              ('kuriur', 1.0),
#              ('kurng', 1.0),
#              ('kut', 1.0),
#              ('la', 213.0),
#              ('label', 6.0),
#              ('lada', 2.0),
#              ('lagi', 75.0),
#              ('lain', 78.0),
#              ('laju', 11.0),
#              ('lakukan', 1.0),
#              ('lalang', 1.0),
#              ('lalu', 1.0),
#              ('lama', 67.0),
#              ('lambat', 83.0),
#              ('lambt', 1.0),
#              ('langsung', 31.0),
#              ('lansung', 4.0),
#              ('lapar', 1.0),
#              ('lapik', 1.0),
#              ('lapis', 24.0),
#              ('lari', 1.0),
#              ('last', 10.0),
#              ('lasum', 1.0),
#              ('lately', 2.0),
#              ('latest', 1.0),
#              ('lautan', 1.0),
#              ('layak', 1.0),
#              ('layan', 1.0),
#              ('layanan', 3.0),
#              ('lbh', 3.0),
#              ('lease', 1.0),
#              ('least', 4.0),
#              ('lebih', 31.0),
#              ('lebur', 2.0),
#              ('legam', 1.0),
#              ('lekat', 1.0),
#              ('lekor', 1.0),
#              ('lelong', 1.0),
#              ('lem', 2.0),
#              ('lemak', 1.0),
#              ('lemau', 22.0),
#              ('lembab', 5.0),
#              ('lembap', 1.0),
#              ('lembik', 5.0),
#              ('lembut', 15.0),
#              ('lempar', 1.0),
#              ('lempeng', 1.0),
#              ('lepas', 40.0),
#              ('leper', 3.0),
#              ('lerai', 1.0),
#              ('les', 2.0),
#              ('letak', 20.0),
#              ('letal', 1.0),
#              ('lewat', 2.0),
#              ('liat', 3.0),
#              ('lihat', 2.0),
#              ('like', 2.0),
#              ('limau', 1.0),
#              ('lingkup', 1.0),
#              ('liut', 1.0),
#              ('lmabt', 1.0),
#              ('lngsung', 2.0),
#              ('location', 2.0),
#              ('logik', 2.0),
#              ('long', 1.0),
#              ('looking', 1.0),
#              ('loye', 1.0),
#              ('lpisan', 1.0),
#              ('ltak', 1.0),
#              ('luar', 7.0),
#              ('luck', 2.0),
#              ('lumpur', 2.0),
#              ('luput', 1.0),
#              ('lutut', 1.0),
#              ('maaf', 26.0),
#              ('maafkan', 1.0),
#              ('macam', 154.0),
#              ('macamana', 2.0),
#              ('macaron', 3.0),
#              ('macarons', 1.0),
#              ('made', 1.0),
#              ('mahal', 6.0),
#              ('mahu', 1.0),
#              ('mai', 1.0),
#              ('main', 9.0),
#              ('mainan', 1.0),
#              ('maintain', 1.0),
#              ('majlis', 1.0),
#              ('maju', 2.0),
#              ('mak', 9.0),
#              ...])

# %% [markdown]
# ### c. Count frequency of words in each classes --> count(pos) and count(neg)

# %%
count_neg = len(count_wdict_neg)
count_neg
# Out:
# 1983

# %% [markdown]
# ### d. count total of word in all classes --> N

# %%
# N value
N = count_pos+count_neg
N
# Out:
# 3698

# %% [markdown]
# ## Step 2: Calculate PMI score for each word

# %%
# print all values needed in positive class
w = 'sama'
cwordpos = count_wdict_pos[w]
cword  = all_word_dict[w]
ctotalwordpos = count_pos
print ('count(w,pos):', cwordpos)
print ('count(pos):', ctotalwordpos)
print ('count(w):', cwordpos)
print ('N:', N)
# Out:
# count(w,pos): 6.0
# count(pos): 1715
# count(w): 6.0
# N: 3698

# %%
#pmi score calculation
import math

def pmi(cw, N, cwsenti, cwwsenti):
    nomi= cwwsenti * N 
    denom = cw * cwsenti
    pmi_score = math.log(nomi/denom,2)
    return pmi_score

mypmi_score = pmi(6,3698,6,6)
mypmi_score
# Out:
# 9.267567008683042

# %%
#save sFrame of adjusted TFIDF
tc.SFrame.save(sf_PMI_pos,"sframe_adjustedTFIDF_pos")
tc.SFrame.save(sf_PMI_neg,"sframe_adjustedTFIDF_neg")
